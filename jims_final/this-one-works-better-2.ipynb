# %%
"""
Hybrid Energy System Simulation Function
Based on NSGA-II Optimization Algorithm

CORRECTED VERSION with proper unit conversions and cost calculations
"""

import numpy as np
import pandas as pd
from typing import Dict, Tuple, List


class HybridEnergySystem:
    """
    Simulates a hybrid renewable energy system with:
    - Photovoltaic (PV) panels
    - Wind Turbines (WT)
    - Hydrogen Storage (H2)
    - Fuel Cell (FC)
    - Electrolyzer (EL)
    - Diesel Generator (DG)
    
    UNIT CONVENTIONS:
    - Power: kW (kilowatts)
    - Energy: kWh (kilowatt-hours)
    - Hydrogen mass: kg (kilograms)
    - Time: hours
    - Currency: USD ($)
    """
    
    def __init__(self, parameters: Dict):
        """
        Initialize system parameters.

        Parameters
        ----------
        parameters : dict
            Dictionary containing all system parameters, grouped as follows:

            GENERATOR CONFIGS:
            - rated_PV          : float  - Rated power per PV panel (kW). Default: 0.327
            - v_cut_in          : float  - Wind turbine cut-in speed (m/s). Default: 2.75
            - v_rated           : float  - Wind turbine rated speed (m/s). Default: 9.0
            - rated_power       : float  - Rated power per wind turbine (kW). Default: 25.0
            - Cap_H2            : float  - Capacity of one H2 storage unit (kg). Default: 6
            - Cap_FC            : float  - Rated power of one fuel cell unit (kW). Default: 2
            - Cap_EL            : float  - Rated power of one electrolyzer unit (kW). Default: 2
            - Cap_DG            : float  - Rated power of one diesel generator unit (kW). Default: 50
            - H_min_percentage  : float  - Minimum H2 storage level as fraction of capacity (0-1). Default: 0
            - H_max_percentage  : float  - Maximum H2 storage level override as fraction (0-1). Default: 0

            DIESEL FUEL CURVE CONSTANTS:
            - f_0               : float  - Intercept coefficient (litre/kW/h). Default: 0.246
            - f_1               : float  - Slope coefficient (litre/kWh). Default: 0.08145

            EFFICIENCY PARAMETERS:
            - eta_PV            : float  - PV panel efficiency, 0-1. Default: 0.15
            - eta_FC            : float  - Fuel cell electrical efficiency, 0-1. Default: 0.50
            - eta_EL            : float  - Electrolyzer efficiency, 0-1. Default: 0.70
            - eta_INVT          : float  - Inverter efficiency, 0-1. Default: 0.90
            - H2_LHV            : float  - Hydrogen lower heating value (kWh/kg). Default: 33.3

            CAPITAL COSTS (one-time investment):
            - c_PV              : float  - PV capital cost ($/kW). Default: 1300
            - c_WT              : float  - Wind turbine capital cost ($/kW). Default: 2300
            - c_H2              : float  - Hydrogen storage capital cost ($/kg capacity). Default: 500
            - c_FC_cap          : float  - Fuel cell capital cost ($/kW). Default: 2000
            - c_EL_cap          : float  - Electrolyzer capital cost ($/kW). Default: 1500
            - c_DG_cap          : float  - Diesel generator capital cost ($/kW). Default: 500
            - c_INVT            : float  - Inverter capital cost, flat total ($). Default: 300

            OPERATING COSTS:
            - c_FC              : float  - Fuel cell operating cost ($/kWh produced). Default: 0
            - c_DG              : float  - Diesel generator operating cost ($/kWh produced). Default: 0
            - c_EL              : float  - Electrolyzer operating cost ($/kWh consumed). Default: 0
            - c_DG_FUEL         : float  - Diesel fuel cost ($/litre). Default: 0.82

            OPERATION & MAINTENANCE COSTS:
            - om_PV             : float  - PV O&M ($/kW/year). Default: 10
            - om_WT             : float  - Wind turbine O&M ($/kW/year). Default: 69
            - om_H2             : float  - Hydrogen storage O&M ($/kg/year). Default: 10
            - om_FC             : float  - Fuel cell O&M ($/kW/year). Default: 30
            - om_EL             : float  - Electrolyzer O&M ($/kW/year). Default: 25
            - om_DG             : float  - Diesel generator O&M ($/operating hour). Default: 0.03
            - om_INVT           : float  - Inverter O&M ($). Default: 0

            REPLACEMENT COSTS (present value, per unit capacity):
            - rc_PV             : float  - PV replacement cost ($/kW). Default: 0
            - rc_WT             : float  - Wind turbine replacement cost ($/kW). Default: 1750
            - rc_H2             : float  - Hydrogen storage replacement cost ($/kg). Default: 10
            - rc_FC             : float  - Fuel cell replacement cost ($/kW). Default: 30
            - rc_EL             : float  - Electrolyzer replacement cost ($/kW). Default: 25
            - rc_DG             : float  - Diesel generator replacement cost ($/kW). Default: 500
            - rc_INVT           : float  - Inverter replacement cost, flat total ($). Default: 300

            EMISSION FACTORS:
            - e_FC              : float  - Fuel cell emissions (kg CO2/kWh). Default: 0.0
            - e_DG              : float  - Diesel generator emissions (kg CO2/litre). Default: 2.6391
            - e_EL              : float  - Electrolyzer direct emissions (kg CO2/kWh). Default: 0.0

            ECONOMIC PARAMETERS:
            - T_life            : int    - Project lifetime (years). Default: 20
            - r                 : float  - Annual discount rate, e.g. 0.05 = 5%. Default: 0.05
            - p_grid            : float  - Grid energy selling price ($/kWh). Default: 0.08

            TECHNICAL PARAMETERS:
            - A_PV              : float  - PV panel area per kW capacity (m²/kW). Default: 6.67
            - P_DG_min          : float  - Minimum diesel generator load ratio, 0-1. Default: 0.3

            COMPONENT LIFETIMES (years):
            - life_PV           : int    - PV panel lifetime. Default: 25
            - life_WT           : int    - Wind turbine lifetime. Default: 20
            - life_H2           : int    - Hydrogen storage lifetime. Default: 20
            - life_FC           : int    - Fuel cell lifetime. Default: 10
            - life_EL           : int    - Electrolyzer lifetime. Default: 15
            - life_DG           : int    - Diesel generator lifetime. Default: 15
            - life_INVT         : int    - Inverter lifetime. Default: 15

            FUNCTIONALITY:
            - output_simulation : Bool     - Set True to output .csv file of the simulation
        """
        # =================================================================
        # Hudai Configs
        # =================================================================

        self.load_scaler = parameters.get('load_scaler',1)

        # =================================================================
        # Generator configs
        # =================================================================
        self.rated_PV = parameters.get('rated_PV',0.327)
        self.v_cut_in = parameters.get('v_cut_in', 2.75)   # Cut-in wind speed (m/s)
        self.v_rated =  parameters.get('v_rated', 9.0)  # Rated wind speed (m/s)
        self.rated_power = parameters.get('rated_power', 25.0) #wind turbine rated power
        self.Cap_H2 = parameters.get('Cap_H2',6) #kg Capacity of 1 H2 storage
        self.Cap_FC = parameters.get('Cap_FC',2) #kW Capacity/Rated power of FC
        self.Cap_EL = parameters.get('Cap_EL',2) #kW Capacity/Rated power of Electrolyzer
        self.Cap_DG = parameters.get('Cap_DG',50) #kW Capacity/Rated power of Diesel
        self.H_min_percentage = parameters.get('H_min_percentage',0) 
        self.H_max_percentage = parameters.get('H_max_percentage',0)

        # =================================================================
        # Diesel Constants
        # =================================================================
        self.f_0 = parameters.get('f_0', 0.246)#litre/kW/h
        self.f_1 = parameters.get('f_1', 0.08145)#litre/kWh





        # =================================================================
        # EFFICIENCY PARAMETERS
        # =================================================================
        self.eta_PV = parameters.get('eta_PV', 0.15)  # PV efficiency (fraction)
        self.eta_FC = parameters.get('eta_FC', 0.50)  # Fuel cell efficiency (fraction)
        self.eta_EL = parameters.get('eta_EL', 0.70)  # Electrolyzer efficiency (fraction)
        self.eta_INVT = parameters.get('eta_INVT', 0.90)  # Inverter efficiency (fraction)
        
        # Hydrogen energy content (thermodynamic constant)
        self.H2_LHV = parameters.get('H2_LHV', 33.3)  # kWh/kg (Lower Heating Value)
        
        # =================================================================
        # CAPITAL COSTS ($/unit)
        # =================================================================
        self.c_PV = parameters.get('c_PV', 1300)      # $/kW
        self.c_WT = parameters.get('c_WT', 2300)      # $/kW
        self.c_H2 = parameters.get('c_H2', 500)       # $/kg capacity
        self.c_FC_cap = parameters.get('c_FC_cap', 2000)  # $/kW
        self.c_EL_cap = parameters.get('c_EL_cap', 1500)  # $/kW
        self.c_DG_cap = parameters.get('c_DG_cap', 500)   # $/kW
        self.c_INVT = parameters.get('c_INVT',300)
        
        # =================================================================
        # OPERATING COSTS ($/kWh)
        # =================================================================
        self.c_FC = parameters.get('c_FC', 0)  # $/kWh produced
        self.c_DG = parameters.get('c_DG', 0)  # $/kWh produced (diesel fuel)
        self.c_EL = parameters.get('c_EL', 0)  # $/kWh consumed
        self.c_DG_FUEL = parameters.get('c_DG_FUEL',0.82)  #$/litre diesel consumed

        
        # =================================================================
        # O&M COSTS ($/unit/year)
        # =================================================================
        self.om_PV = parameters.get('om_PV', 10)  # $/kW/year
        self.om_WT = parameters.get('om_WT', 69)  # $/kW/year
        self.om_H2 = parameters.get('om_H2', 10)  # $/kg/year
        self.om_FC = parameters.get('om_FC', 30)  # $/kW/year
        self.om_EL = parameters.get('om_EL', 25)  # $/kW/year
        self.om_DG = parameters.get('om_DG', 0.03)  # $/h
        self.om_INVT = parameters.get('om_INVT',0) 


        # Replacement COSTS(rc) ($/unit/year)
        # =================================================================
        self.rc_PV = parameters.get('rc_PV', 0)  # $/kW
        self.rc_WT = parameters.get('rc_WT', 1750)  # $/kW
        self.rc_H2 = parameters.get('rc_H2', 10)  # $/kg
        self.rc_FC = parameters.get('rc_FC', 30)  # $/kW
        self.rc_EL = parameters.get('rc_EL', 25)  # $/kW
        self.rc_DG = parameters.get('rc_DG', 500)  # $/kW
        self.rc_INVT = parameters.get('rc_INVT',300) # per piece


        
        # =================================================================
        # EMISSION FACTORS (kg CO2/kWh)
        # =================================================================
        self.e_FC = parameters.get('e_FC', 0.0)   # Assuming H2 from renewables
        self.e_DG = parameters.get('e_DG', 2.6391)   # 2.6391 kg/Litre Diesel emissions
        self.e_EL = parameters.get('e_EL', 0.0)   # Electrolyzer direct emissions
        
        # =================================================================
        # ECONOMIC PARAMETERS
        # =================================================================
        self.T_life = parameters.get('T_life', 20)    # Project lifetime (years)
        self.r = parameters.get('r', 0.05)            # Discount rate
        self.p_grid = parameters.get('p_grid', 0.08)  # Grid selling price ($/kWh)
        
        # =================================================================
        # TECHNICAL PARAMETERS
        # =================================================================
        self.A_PV = parameters.get('A_PV', 6.67)      # PV area per kW (m²/kW)
        self.P_DG_min = parameters.get('P_DG_min', 0.3)  # Minimum DG load ratio
        # self.DG_CAPACITY = parameters.get('DG_CAPACITY') #DG capacity
        # self.DG_RATED = parameters.get('DG_RATED',50) #DG Rated Capacity
        
        # =================================================================
        # COMPONENT LIFETIMES (years)
        # =================================================================
        self.life_PV = parameters.get('life_PV', 25)
        self.life_WT = parameters.get('life_WT', 20)
        self.life_H2 = parameters.get('life_H2', 20)
        self.life_FC = parameters.get('life_FC', 10)
        self.life_EL = parameters.get('life_EL', 15)
        self.life_DG = parameters.get('life_DG', 15)
        self.life_INVT = parameters.get('life_INVT', 15)

        # =================================================================
        # FUNCTIONALITY
        # =================================================================
        
        self.output_simulation = parameters.get('output_simulation',False)

    
    
    def wind_power_curve(self, v: float) -> float:
        """
        Calculate wind turbine power output based on wind speed
        Using a simplified power curve model
        
        Parameters
        ----------
        v : float
            Wind speed (m/s)
        rated_power : float
            Rated power of wind turbine (kW)
            Default: 1.0 kW (for per-kW calculations)
            
        Returns
        -------
        float
            Power output (kW)
        """
        # v_cut_in = 2.75   # Cut-in wind speed (m/s)
        # v_rated = 9.0   # Rated wind speed (m/s)
        # # v_cut_out = 25.0 # Cut-out wind speed (m/s)
        # rated_power = 20
        
        if v < self.v_cut_in :
            return 0.0
        elif v >= self.v_cut_in and v < self.v_rated:
            # Cubic relationship between cut-in and rated
            return self.rated_power * ((v**3 - self.v_cut_in**3) / (self.v_rated**3 - self.v_cut_in**3))
        else:  # v_rated <= v <= v_cut_out
            return self.rated_power
    
    
    def calculate_replacement_cost(self, system: Dict, T_life: int, r: float) -> float:
        """
        Calculate the total present value of all component replacement costs
        over the project lifetime.

        A replacement occurs at years: life, 2*life, 3*life, ...
        Any replacement that falls exactly on or after T_life is excluded
        (the project is over; you wouldn't replace something on the last day).

        Parameters
        ----------
        system : dict
            System configuration (N_PV, N_WT, N_H2, N_FC, N_EL, N_DG)
        T_life : int
            Project lifetime (years)
        r : float
            Annual discount rate (e.g. 0.05 = 5%)

        Returns
        -------
        float
            Present value of all replacement costs ($)
        """
        C_rep = 0.0

        # ------------------------------------------------------------------
        # Per-unit components
        # Each tuple: (system_key, capacity_per_unit, replacement_cost_per_unit_capacity, lifetime)
        # Uses rc_* parameters (replacement costs), NOT c_* (capital costs)
        # ------------------------------------------------------------------
        components = [
            ('N_PV', self.rated_PV,    self.rc_PV,  self.life_PV),
            ('N_WT', self.rated_power, self.rc_WT,  self.life_WT),
            ('N_H2', self.Cap_H2,      self.rc_H2,  self.life_H2),
            ('N_FC', self.Cap_FC,      self.rc_FC,  self.life_FC),
            ('N_EL', self.Cap_EL,      self.rc_EL,  self.life_EL),
            ('N_DG', self.Cap_DG,      self.rc_DG,  self.life_DG),
        ]

        for comp_key, capacity_per_unit, rc_per_unit_capacity, life in components:
            n_units = system.get(comp_key, 0)

            # Skip if component not present or outlasts the project
            if n_units == 0 or life <= 0 or life >= T_life:
                continue

            # Total replacement cost for this component (one replacement event)
            total_rc = n_units * capacity_per_unit * rc_per_unit_capacity

            # Replacement years: life, 2*life, ... up to but NOT including T_life
            replacement_year = life
            while replacement_year < T_life:
                C_rep += total_rc / ((1 + r) ** replacement_year)
                replacement_year += life

        # ------------------------------------------------------------------
        # Inverter: single flat cost (c_INVT is a total $ amount, not per-kW)
        # Uses rc_INVT; falls back to c_INVT if rc_INVT is 0
        # ------------------------------------------------------------------
        invt_rc = self.rc_INVT if self.rc_INVT > 0 else self.c_INVT

        if invt_rc > 0 and self.life_INVT > 0 and self.life_INVT < T_life:
            replacement_year = self.life_INVT
            while replacement_year < T_life:
                C_rep += invt_rc / ((1 + r) ** replacement_year)
                replacement_year += self.life_INVT

        return C_rep  
      
    def simulate_year(self, system: Dict, data: pd.DataFrame) -> Tuple[float, float, float, Dict]:
        """
        Simulate one year of system operation
        
        Parameters
        ----------
        system : dict
            System configuration containing:
            - N_PV: number of PV 
            - N_WT: number of Wind turbines 
            - N_H2: Hydrogen storage capacity (kg)
            - N_FC: Fuel cell capacity (kW)
            - N_EL: Electrolyzer capacity (kW)
            - N_DG: Diesel generator capacity (kW)
        
        data : pd.DataFrame
            Hourly data with columns:
            - 'Solar Power','Solar Irradiance (W/sq.m)' or 'Avg Solar Irradiance'
            - 'Wind Speed (m/s)' or 'Avg Wind Speed'
            - 'Community Load' and/or 'RO Load (kWh)'
            
        Returns
        -------
        Tuple[float, float, float, Dict]
            C_total: Total annualized cost ($/year)
            E_total: Total annual emissions (kg CO2/year)
            LPSP: Loss of power supply probability (0-1)
            details: Dictionary with detailed results
        """
        # =================================================================
        # EXTRACT SYSTEM CONFIGURATION
        # =================================================================

        N_PV = system.get('N_PV', 0)
        N_WT = system.get('N_WT', 0)
        Capacity_H2 = system.get('N_H2', 0)*self.Cap_H2
        Capacity_FC = system.get('N_FC', 0)*self.Cap_FC
        Capacity_EL = system.get('N_EL', 0)*self.Cap_EL
        Capacity_DG = system.get('N_DG', 0)*self.Cap_DG
 
        # Validate inputs
        if Capacity_H2 < 0 or Capacity_FC < 0 or Capacity_EL < 0:
            raise ValueError("Capacities cannot be negative")
        
        # =================================================================
        # HYDROGEN STORAGE LIMITS
        # =================================================================
        H_max = Capacity_H2  # Maximum hydrogen storage (kg)
        H_min = self.H_min_percentage * Capacity_H2  # Minimum hydrogen level (10% of capacity)
        
        # =================================================================
        # INITIALIZE TRACKING VARIABLES
        # =================================================================
        C_op = 0.0       # Operating cost ($)
        E_CO2 = 0.0      # CO2 emissions (kg)
        E_unmet = 0.0    # Unmet energy (kWh)
        E_grid = 0.0     # Energy sold to grid (kWh)
        
        E_PV_total = 0.0
        E_WT_total = 0.0
        E_FC_total = 0.0
        E_EL_total = 0.0
        E_DG_total = 0.0

        # Hourly log storage
        hourly_log = []
        
        # Initialize hydrogen storage trajectory
        H = np.zeros(len(data) + 1)
        H[0] = 1 * Capacity_H2  # Start at 100% capacity
        
        # =================================================================
        # DETECT COLUMN NAMES
        # =================================================================
        # if 'Solar Irradiance (W/sq.m)' in data.columns:
        #     irrad_col = 'Solar Irradiance (W/sq.m)'
        # elif 'Avg Solar Irradiance' in data.columns:
        #     irrad_col = 'Avg Solar Irradiance'
        # else:
        #     raise ValueError("Solar irradiance column not found in data")
        

        if 'Solar Power' in data.columns:
            avg_solar_col = 'Solar Power'

        else:
            raise ValueError("Solar Power column not found in data")
        
        if 'Avg Wind Speed NASA (36m)' in data.columns:
            wind_col = 'Avg Wind Speed NASA (36m)'
        elif 'Avg Wind Speed' in data.columns:
            wind_col = 'Avg Wind Speed'
        else:
            raise ValueError("Wind speed column not found in data")
        
        # =================================================================
        # CALCULATE TOTAL LOAD
        # =================================================================
        L = data['Community Load'].values.copy()
        L = self.load_scaler * L
        # if 'RO Load (kWh)' in data.columns:
        #     L = L + 0*data['RO Load (kWh)'].values
        
        L_year = np.sum(L)  # Total annual load (kWh)
        if self.output_simulation:

            print(len(data))          # Should be 8760 for hourly annual data
            print(L.sum())  # Should match ~1,096,946
            print(pd.Series(L).describe())
        
        # =================================================================
        # HOURLY SIMULATION LOOP
        # =================================================================
        for t in range(len(data)):
            # Get hourly inputs
            # I_t = data.iloc[t][irrad_col] / 1000.0  # Convert W/m² to kW/m²
            v_t = data.iloc[t][wind_col]            # Wind speed (m/s)
            PV_t = data.iloc[t][avg_solar_col]
            L_t = L[t]                               # Load (kWh for this hour)

            E_FC = 0.0
            E_DG = 0.0
            E_deficit_logged = 0.0
            E_surplus_logged = 0.0
            E_EL_AC = 0.0
                        
            # ---------------------------------------------------------
            # RENEWABLE ENERGY GENERATION
            # ---------------------------------------------------------
            # PV generation: Power = efficiency × area × irradiance × capacity
            
            E_PV = PV_t * N_PV*self.eta_INVT  # kWh AC
            # Wind generation: Power = power_curve(wind_speed) × capacity
            E_WT = self.wind_power_curve(v_t) * N_WT  # kWh AC
            
            E_RE = E_PV + E_WT  # Total renewable energy AC (kWh)
            
            E_PV_total += E_PV
            E_WT_total += E_WT
            
            # ---------------------------------------------------------
            # NET POWER BALANCE
            # ---------------------------------------------------------
            E_net = E_RE - L_t  # Positive = surplus, Negative = deficit
            
            # =============================================================
            # CASE 1: DEFICIT (E_net < 0)
            # =============================================================
            if E_net < 0:
                E_grid_hour = 0.0
                E_deficit = abs(E_net)  # kWh needed
                E_FC = 0.0
                E_DG = 0.0
                
                # ---------------------------------------------------------
                # STEP 1: TRY FUEL CELL FIRST
                # ---------------------------------------------------------
                if H[t] > H_min and Capacity_FC > 0:
                    # -------------------------------------------------
                    # FUEL CELL OPERATION
                    # DC chain: H2 -> [FC, eta_FC] -> DC -> [Inverter, eta_INVT] -> AC load
                    # -------------------------------------------------
                    # Maximum H2 available for use (kg)
                    H2_available = H[t] - H_min
                    
                    # Maximum energy from available H2 (kWh) - in DC terms (pre-inverter)
                    # Energy = H2_mass × LHV × efficiency
                    E_FC_max_from_H2 = H2_available * self.H2_LHV * self.eta_FC
                    
                    # Maximum energy from FC capacity (kWh in 1 hour) - in DC terms
                    E_FC_max_from_cap = Capacity_FC * 1.0  # kW × 1 hour
                    
                    # Actual FC DC limit is minimum of both constraints
                    E_FC_max = min(E_FC_max_from_H2, E_FC_max_from_cap)
                    
                    # Convert AC deficit to DC equivalent to compare against DC limits
                    E_deficit_DC = E_deficit / self.eta_INVT

                    # FC DC output: limited by DC capacity and DC deficit requirement
                    E_FC_DC = min(E_deficit_DC, E_FC_max)

                    # Convert DC output to AC output delivered to load (through inverter)
                    E_FC = E_FC_DC * self.eta_INVT
                    
                    # H2 consumed (kg) - based on DC energy into inverter
                    # H2_consumed = DC_Energy / (LHV × eta_FC)
                    H2_consumed = E_FC_DC / (self.H2_LHV * self.eta_FC)
                    
                    # Update hydrogen storage---------------------------
                    H[t+1] = max(0, H[t] - H2_consumed)
                    
                    # Add costs and emissions (tracked in AC terms, consistent with load)
                    C_op += self.c_FC * E_FC
                    E_CO2 += self.e_FC * E_FC
                    E_FC_total += E_FC
                    
                    # Update remaining deficit (in AC terms)
                    E_deficit = E_deficit - E_FC
                else:
                    # No fuel cell available, keep current H2 level
                    H[t+1] = H[t]
                
                # ---------------------------------------------------------
                # STEP 2: IF STILL DEFICIT, TRY DIESEL GENERATOR
                # ---------------------------------------------------------
                if E_deficit > 0.001 and Capacity_DG > 0:  # Small tolerance
                    # -------------------------------------------------
                    # DIESEL GENERATOR OPERATION
                    # -------------------------------------------------
                    # Diesel generator must run above minimum load
                    P_DG_min_abs = self.P_DG_min * self.Cap_DG  # Minimum power (kW)
                    # Check if deficit is within operable range
                    if E_deficit >= P_DG_min_abs:
                        # DG can operate
                        E_DG = min(E_deficit, Capacity_DG)  # Limited by capacity
                        #We can choose to run the DG several times to minimize deficit
                        #As long as we are being above the minimum so if deficit is 5c and capacity is c
                        #we run DG 5 times. If deficit is 5c+k, then unmet load is k

                        

                        DG_Litre = self.f_1 * Capacity_DG + self.f_0 * E_DG

                        # Add costs and emissions
                        C_op += self.c_DG_FUEL * DG_Litre
                        E_CO2 += self.e_DG * DG_Litre
                        E_DG_total += E_DG
                        
                        # Update remaining deficit
                        E_deficit = E_deficit - E_DG
                    # else: deficit too small for DG minimum load, remains unmet
                
                # ---------------------------------------------------------
                # STEP 3: ANY REMAINING DEFICIT IS UNMET LOAD
                # ---------------------------------------------------------
                if E_deficit > 0.001:  # Small tolerance
                    E_unmet += E_deficit
            
            # =============================================================
            # CASE 2: SURPLUS (E_net > 0)
            # =============================================================
            elif E_net > 0:
                E_surplus = E_net  # kWh available (AC)
                
                # Check if storage has space and electrolyzer exists
                if H[t] < H_max and Capacity_EL > 0:
                    # -------------------------------------------------
                    # ELECTROLYZER OPERATION
                    # AC chain: AC surplus -> [Rectifier, eta_INVT] -> DC -> [Electrolyzer, eta_EL] -> H2
                    # -------------------------------------------------
                    # Available storage space (kg)
                    H2_space = H_max - H[t]
                    
                    # Maximum energy that can be converted to H2 based on storage space
                    # Energy = H2_mass / (efficiency / LHV)
                    # H2_produced = Energy × efficiency / LHV
                    # So: Energy_max = H2_space × LHV / efficiency  (in DC terms)
                    E_EL_max_from_storage = H2_space * self.H2_LHV / self.eta_EL
                    
                    # Maximum energy from EL capacity (kWh in 1 hour) - in DC terms
                    E_EL_max_from_cap = Capacity_EL * 1.0  # kW × 1 hour

                    # Maximum DC available from AC surplus through rectifier
                    E_surplus_DC = E_surplus * self.eta_INVT

                    # Actual EL DC input is minimum of all constraints
                    E_EL_DC = min(E_surplus_DC, E_EL_max_from_storage, E_EL_max_from_cap)

                    # AC consumed from the bus to supply the rectifier
                    E_EL_AC = E_EL_DC / self.eta_INVT
                    
                    # H2 produced (kg) - based on DC energy into electrolyzer
                    # H2_produced = DC_Energy × efficiency / LHV
                    H2_produced = E_EL_DC * self.eta_EL / self.H2_LHV
                    
                    # Update hydrogen storage
                    H[t+1] = min(H_max, H[t] + H2_produced)
                    
                    # Add costs and emissions (tracked in AC terms, consistent with load)
                    C_op += self.c_EL * E_EL_AC
                    E_CO2 += self.e_EL * E_EL_AC
                    E_EL_total += E_EL_AC
                    
                    # Remaining surplus after electrolysis (both in AC terms)
                    E_leftover = E_surplus - E_EL_AC  # subtract the AC consumed, not DC
                    
                    if E_leftover > 0.001:  # Small tolerance
                        # Sell leftover to grid
                        E_grid += E_leftover
                        E_grid_hour = E_leftover
                        C_op -= self.p_grid * E_leftover  # Revenue (negative cost)
                else:
                    # Storage is full or no electrolyzer, sell all surplus to grid
                    H[t+1] = H[t]
                    E_grid += E_surplus
                    E_grid_hour = E_surplus
                    C_op -= self.p_grid * E_surplus  # Revenue (negative cost)
            
            # =============================================================
            # CASE 3: BALANCED (E_net == 0)
            # =============================================================
            else:
                E_grid_hour = 0.0
                H[t+1] = H[t]
            if self.output_simulation:
                hourly_log.append({
                    'Hour': t,
                    'Community Load': L_t,
                    'Solar Power': PV_t,
                    'Wind Power': self.wind_power_curve(v_t),
                    'PV Generation': E_PV,
                    'WT Generation': E_WT,
                    'FC Generation': E_FC,
                    'DG Generation': E_DG,
                    'Unmet Energy': E_deficit if (E_net < 0 and E_deficit > 0.001) else 0.0,
                    'Surplus Energy': E_grid_hour,
                    'H2 Capacity': H[t+1],
                    })
        
        # Export hourly log to CSV
        if self.output_simulation:

            hourly_df = pd.DataFrame(hourly_log)
            hourly_df.to_csv('simulation_hourly_log.csv', index=False)
            print("Hourly log saved to simulation_hourly_log.csv")

        # =================================================================
        # CALCULATE PERFORMANCE METRICS
        # =================================================================
        # Loss of Power Supply Probability
        
        LPSP = E_unmet / L_year if L_year > 0 else 0.0
        
        # =================================================================
        # CALCULATE COSTS
        # =================================================================
        # Capital cost (present value)
        C_cap = (self.c_PV * N_PV*self.rated_PV + 
                 self.c_WT * N_WT*self.rated_power + #wind 
                 self.c_H2 * Capacity_H2 + 
                 self.c_FC_cap * Capacity_FC + 
                 self.c_EL_cap * Capacity_EL + 
                 self.c_DG_cap * Capacity_DG +
                 self.c_INVT)
        
        # Annual O&M cost
        # print(f"CapacityDG = {Capacity_DG}")
        C_om_annual = (self.om_PV * N_PV*self.rated_PV + 
                       self.om_WT * N_WT*self.rated_power + 
                       self.om_H2 * Capacity_H2 + 
                       self.om_FC * Capacity_FC + 
                       self.om_EL * Capacity_EL + 
                       self.om_DG * (E_DG_total/Capacity_DG if Capacity_DG>0 else 0))
        
        # Replacement cost (present value)
        C_rep = self.calculate_replacement_cost(system, self.T_life, self.r)
        
        # Capital Recovery Factor (CRF)
        # Converts present value to equivalent annual cost
        if self.r > 0:
            CRF = (self.r * (1 + self.r) ** self.T_life) / ((1 + self.r) ** self.T_life - 1)
        else:
            CRF = 1.0 / self.T_life
        
        # Total annualized cost
        # = Annualized capital + Annualized replacement + Annual O&M + Annual operating
        C_total = (C_cap + C_rep) * CRF + C_om_annual + C_op
        
        # Total emissions
        E_total = E_CO2
        
        # =================================================================
        # PREPARE DETAILED RESULTS
        # =================================================================
        details = {
            'C_total':C_total,
            'C_cap': C_cap,
            'C_rep': C_rep,
            'C_om_annual': C_om_annual,
            'C_op': C_op,
            'CRF': CRF,
            'E_PV_total': E_PV_total,
            'E_WT_total': E_WT_total,
            'E_FC_total': E_FC_total,
            'E_EL_total': E_EL_total,
            'E_DG_total': E_DG_total,
            'E_grid': E_grid,
            'E_unmet': E_unmet,
            'L_year': L_year,
            'H_trajectory': H,
            'hourly_df' : hourly_df if self.output_simulation else None,
        }
        
        return C_total, E_total, LPSP, details

# %%
"""
Example Script: Running the CORRECTED Hybrid Energy System Simulation

This script demonstrates the corrected version with proper unit conversions
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



def run_single_simulation(data,parameters,config):

    """


    Run a single simulation with a given system configuration


    """
    print("="*80)
    print("CORRECTED HYBRID ENERGY SYSTEM SIMULATION")
    print("="*80)

    # =========================================================================
    # CREATE SYSTEM INSTANCE
    # =========================================================================
    system = HybridEnergySystem(parameters)
    


    # Derived capacities for display
    cap_PV  = config['N_PV']  * system.rated_PV     # kW
    cap_WT  = config['N_WT']  * system.rated_power  # kW
    cap_H2  = config['N_H2']  * system.Cap_H2       # kg
    cap_FC  = config['N_FC']  * system.Cap_FC        # kW
    cap_EL  = config['N_EL']  * system.Cap_EL        # kW
    cap_DG  = config['N_DG']  * system.Cap_DG        # kW
    
    print("\n" + "="*80)
    print("SYSTEM CONFIGURATION")
    print("="*80)
    print(f"  PV Capacity: RatedPV {system.rated_PV:>4}kW              {config['N_PV']:>4} panels  ->  {cap_PV:>8.2f} kW")
    print(f"  Wind Turbine Capacity: Rated Power {system.rated_power:>4}kW    {config['N_WT']:>4} turbines ->  {cap_WT:>8.2f} kW")
    print(f"  H2 Storage Capacity: CapH2 {system.Cap_H2:>4}kg      {config['N_H2']:>4} units   ->  {cap_H2:>8.2f} kg")
    print(f"  Fuel Cell Capacity: CapFC {system.Cap_FC:>4}kW       {config['N_FC']:>4} units   ->  {cap_FC:>8.2f} kW")
    print(f"  Electrolyzer Capacity: CapEL {system.Cap_EL:>4}kW    {config['N_EL']:>4} units   ->  {cap_EL:>8.2f} kW")
    print(f"  Diesel Generator: CapDG {system.Cap_DG:>4}kW         {config['N_DG']:>4} units   ->  {cap_DG:>8.2f} kW")
    
    print("\n" + "="*80)
    print("EFFICIENCY DETAILS")
    print("="*80)
    print(f"  PV Efficiency:            {parameters['eta_PV']*100:>6.1f} %")
    print(f"  Fuel Cell Efficiency:     {parameters['eta_FC']*100:>6.1f} %")
    print(f"  Electrolyzer Efficiency:  {parameters['eta_EL']*100:>6.1f} %")
    print(f"  Inverter Efficiency:      {parameters['eta_INVT']*100:>6.1f} %")
    print(f"  H2 Lower Heating Value:   {parameters['H2_LHV']:>6.1f} kWh/kg")
    print()
    print(f"  FC Output:                {parameters['eta_FC']*parameters['H2_LHV']:>6.2f} kWh per kg H2")
    print(f"  EL Input Required:        {parameters['H2_LHV']/parameters['eta_EL']:>6.2f} kWh per kg H2")
    print(f"  Round-trip Efficiency:    {parameters['eta_FC']*parameters['eta_EL']*100:>6.1f} %")
    
    
    print(f"  Data Points:              {len(data):>8} hours")
    print(f"  Represents:               {len(data)/24:>8.1f} days")
    
    # =========================================================================
    # RUN SIMULATION
    # =========================================================================
    print("\n" + "="*80)
    print("RUNNING SIMULATION...")
    print("="*80)
    
    C_total, E_total, LPSP, details = system.simulate_year(config, data)
    
    # =========================================================================
    # DISPLAY RESULTS
    # =========================================================================
    print("\n" + "="*80)
    print("SIMULATION RESULTS")
    print("="*80)
    
    print("\n--- ECONOMIC PERFORMANCE ---")
    print(f"  Total Annualized Cost:    ${C_total:>12,.2f} /year")
    print(f"  Capital Cost:             ${details['C_cap']:>12,.2f}")
    print(f"  Replacement Cost:         ${details['C_rep']:>12,.2f}")
    print(f"  Annual O&M Cost:          ${details['C_om_annual']:>12,.2f} /year")
    print(f"  Annual Operating Cost:    ${details['C_op']:>12,.2f} /year")
    print(f"  Capital Recovery Factor:  {details['CRF']:>12.6f}")
    
    print("\n--- ENVIRONMENTAL PERFORMANCE ---")
    print(f"  Total Annual Emissions:   {E_total:>12,.2f} kg CO2/year")
    print(f"  Emission Intensity:       {E_total/details['L_year']*1000:>12.4f} g CO2/kWh")
    
    print("\n--- RELIABILITY PERFORMANCE ---")
    print(f"  Loss of Power Supply:     {LPSP*100:>12.4f} %")
    print(f"  Reliability:              {(1-LPSP)*100:>12.4f} %")
    print(f"  Unmet Energy:             {details['E_unmet']:>12,.2f} kWh/year")

    # -------------------------------------------------------------------------
    # Pre-compute derived quantities for energy breakdown
    # -------------------------------------------------------------------------
    E_PV        = details['E_PV_total']
    E_WT        = details['E_WT_total']
    E_FC        = details['E_FC_total']
    E_DG        = details['E_DG_total']
    E_EL        = details['E_EL_total']
    E_spilled   = details['E_grid']
    E_unmet     = details['E_unmet']
    L_year      = details['L_year']

    E_RE_generated  = E_PV + E_WT                        # total renewable generated
    E_total_gen     = E_RE_generated + E_FC + E_DG       # everything generated

    # Renewable energy that actually served the load (not spilled)
    E_RE_consumed   = max(0.0, E_RE_generated - E_spilled-E_EL)

    # Total energy actually consumed by the load
    E_consumed      = L_year - E_unmet                   # = served load

    # Non-renewable share consumed
    E_nonRE_consumed = E_consumed - E_RE_consumed        # FC + DG portion

    # Fractions of CONSUMED energy
    frac_RE_consumed    = E_RE_consumed    / E_consumed  * 100 if E_consumed > 0 else 0
    frac_nonRE_consumed = E_nonRE_consumed / E_consumed  * 100 if E_consumed > 0 else 0
    frac_DG_consumed    = E_DG / E_consumed  * 100 if E_consumed > 0 else 0
    frac_FC_consumed    = E_FC /E_consumed   * 100 if E_consumed > 0 else 0

    # Fractions of TOTAL GENERATION
    frac_PV_gen  = E_PV / E_total_gen * 100 if E_total_gen > 0 else 0
    frac_WT_gen  = E_WT / E_total_gen * 100 if E_total_gen > 0 else 0
    frac_FC_gen  = E_FC / E_total_gen * 100 if E_total_gen > 0 else 0
    frac_DG_gen  = E_DG / E_total_gen * 100 if E_total_gen > 0 else 0
    frac_RE_gen  = E_RE_generated / E_total_gen * 100 if E_total_gen > 0 else 0

    print("\n--- GENERATION (What Was Produced) ---")
    print(f"  Total Generation:         {E_total_gen:>12,.2f} kWh/year  (100.0%)")
    print(f"  - Renewable Subtotal:    {E_RE_generated:>12,.2f} kWh/year  ({frac_RE_gen:>5.1f}%)")
    print(f"      - PV:                {E_PV:>12,.2f} kWh/year  ({frac_PV_gen:>5.1f}%)")
    print(f"      - Wind:              {E_WT:>12,.2f} kWh/year  ({frac_WT_gen:>5.1f}%)")
    print(f"  - Fuel Cell:             {E_FC:>12,.2f} kWh/year  ({frac_FC_gen:>5.1f}%)")
    print(f"  - Diesel Generator:      {E_DG:>12,.2f} kWh/year  ({frac_DG_gen:>5.1f}%)")

    print("\n--- GENERATION ROUTING (Where Did It Go) ---")
    print(f"  Total Generated:          {E_total_gen:>12,.2f} kWh/year")
    print(f"  - Served Load:           {E_consumed:>12,.2f} kWh/year  ({E_consumed/E_total_gen*100:>5.1f}%)")
    print(f"  - Spilled to Grid:       {E_spilled:>12,.2f} kWh/year  ({E_spilled/E_total_gen*100:>5.1f}%)")
    print(f"  - Electrolyzer Input:    {E_EL:>12,.2f} kWh/year  ({E_EL/E_total_gen*100:>5.1f}%)")

    print("\n--- LOAD BREAKDOWN (What the Load Actually Received) ---")
    print(f"  Total Load Demand:        {L_year:>12,.2f} kWh/year  (100.0%)")
    print(f"  - Served:                {E_consumed:>12,.2f} kWh/year  ({E_consumed/L_year*100:>5.1f}%)")
    print(f"      - From Renewables:   {E_RE_consumed:>12,.2f} kWh/year  ({frac_RE_consumed:>5.1f}% of served)")
    print(f"      - From Non-RE:       {E_nonRE_consumed:>12,.2f} kWh/year  ({frac_nonRE_consumed:>5.1f}% of served)")
    print(f"          - From Diesel:   {E_DG:>12,.2f} kWh/year  ({frac_DG_consumed:>5.1f}% of served)")
    print(f"          - From FC:       {E_FC:>12,.2f} kWh/year  ({frac_FC_consumed:>5.1f}% of served)")

    print(f"  - Unmet:                 {E_unmet:>12,.2f} kWh/year  ({E_unmet/L_year*100:>5.1f}%)")

    print("\n--- RENEWABLE FRACTION (Three Ways to Measure) ---")
    print(f"  RE Generated / Load:      {E_RE_generated/L_year*100:>12.2f} %  <- inflated (counts spilled RE)")
    print(f"  RE Generated / Total Gen: {frac_RE_gen:>12.2f} %  <- pie chart number")
    print(f"  RE Consumed / Load Served:{frac_RE_consumed:>12.2f} %  <- most honest")

    print("\n--- COST & PERFORMANCE SUMMARY ---")
    LCOE = C_total / (L_year - E_unmet)
    print(f"  Levelized Cost (LCOE):    ${LCOE:>12.4f} /kWh")

    # Capital cost breakdown
    c_pv_cost  = parameters['c_PV']     * cap_PV
    c_wt_cost  = parameters['c_WT']     * cap_WT
    c_h2_cost  = parameters['c_H2']     * cap_H2
    c_fc_cost  = parameters['c_FC_cap'] * cap_FC
    c_el_cost  = parameters['c_EL_cap'] * cap_EL
    c_dg_cost  = parameters['c_DG_cap'] * cap_DG

    print("\n--- CAPITAL COST BREAKDOWN ---")
    print(f"  Total Capital Cost:       ${details['C_cap']:>12,.2f}  (100.0%)")
    print(f"  - PV System:             ${c_pv_cost:>12,.2f}  ({c_pv_cost/details['C_cap']*100:>5.1f}%)")
    print(f"  - Wind Turbines:         ${c_wt_cost:>12,.2f}  ({c_wt_cost/details['C_cap']*100:>5.1f}%)")
    print(f"  - H2 Storage:            ${c_h2_cost:>12,.2f}  ({c_h2_cost/details['C_cap']*100:>5.1f}%)")
    print(f"  - Fuel Cell:             ${c_fc_cost:>12,.2f}  ({c_fc_cost/details['C_cap']*100:>5.1f}%)")
    print(f"  - Electrolyzer:          ${c_el_cost:>12,.2f}  ({c_el_cost/details['C_cap']*100:>5.1f}%)")
    print(f"  - Diesel Generator:      ${c_dg_cost:>12,.2f}  ({c_dg_cost/details['C_cap']*100:>5.1f}%)")

    print("\n" + "="*80)

    return C_total, E_total, LPSP, system, config, data, details

def plot_results(details, config, system):
    """
    Create visualization of system performance.

    Parameters
    ----------
    details : dict
        Detailed results dict returned by simulate_year()
    config : dict
        System configuration (N_PV, N_WT, N_H2, N_FC, N_EL, N_DG)
    system : HybridEnergySystem
        Instantiated system object (needed for capacities like Cap_H2)
    """
    H_min_level = system.H_min_percentage * config['N_H2'] * system.Cap_H2
    H_max_level = config['N_H2'] * system.Cap_H2

    fig, axes = plt.subplots(2, 1, figsize=(12, 8))
    
    # --- Hydrogen storage trajectory ---
    hours = np.arange(len(details['H_trajectory']))
    axes[0].plot(hours / 24, details['H_trajectory'], linewidth=0.8, label='H2 Level')
    axes[0].axhline(y=H_max_level,  color='red',    linestyle='--', linewidth=1.0, label=f'Max Capacity ({H_max_level:.0f} kg)')
    axes[0].axhline(y=H_min_level,  color='orange', linestyle='--', linewidth=1.0, label=f'Min Level ({H_min_level:.0f} kg)')
    axes[0].set_xlabel('Day')
    axes[0].set_ylabel('Hydrogen Storage (kg)')
    axes[0].set_title('Hydrogen Storage Level Over Time')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # --- Energy generation mix pie chart ---
    energy_sources = ['PV', 'Wind', 'Fuel Cell', 'Diesel']
    energy_values  = [
        details['E_PV_total'],
        details['E_WT_total'],
        details['E_FC_total'],
        details['E_DG_total'],
    ]
    
    # Filter out zero/negligible values for a cleaner chart
    filtered = [(s, v) for s, v in zip(energy_sources, energy_values) if v > 0]
    
    if filtered:
        labels, values = zip(*filtered)
        axes[1].pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
        axes[1].set_title('Energy Generation Mix')
    else:
        axes[1].text(0.5, 0.5, 'No Energy Generated', ha='center', va='center',
                     transform=axes[1].transAxes)
        axes[1].set_title('Energy Generation Mix')
    
    plt.tight_layout()
    plt.savefig(
    f"simulation_results_NP{config['N_PV']}_NW{config['N_WT']}_NH{config['N_H2']}_NF{config['N_FC']}_NE{config['N_EL']}_ND{config['N_DG']}.png",
    dpi=150, bbox_inches='tight'
)
    print("\nPlot saved to: simulation_results_cutin2.75.png")
    plt.close()


def sensitivity_analysis(file_path):
    """
    Perform sensitivity analysis on hydrogen storage capacity
    (number of H2 storage units, N_H2).
    """
    print("\n" + "="*80)
    print("SENSITIVITY ANALYSIS: Hydrogen Storage Capacity")
    print("="*80)
    
    # Base parameters
    parameters = {
        'eta_PV': 0.15, 'eta_FC': 0.50, 'eta_EL': 0.70, 'H2_LHV': 33.3,
        'eta_INVT': 0.90,
        'c_PV': 1500, 'c_WT': 3000, 'c_H2': 500,
        'c_FC_cap': 2000, 'c_EL_cap': 1500, 'c_DG_cap': 400,
        'c_FC': 0, 'c_DG': 0, 'c_EL': 0, 'c_DG_FUEL': 0.82,
        'om_PV': 20, 'om_WT': 50, 'om_H2': 10,
        'om_FC': 30, 'om_EL': 25, 'om_DG': 15,
        'rc_PV': 20, 'rc_WT': 50, 'rc_H2': 10,
        'rc_FC': 30, 'rc_EL': 25, 'rc_DG': 15,
        'e_FC': 0.0, 'e_DG': 2.639, 'e_EL': 0.0,
        'T_life': 20, 'r': 0.05, 'p_grid': 0.08,
        'A_PV': 6.67, 'P_DG_min': 0.3,
        'life_PV': 25, 'life_WT': 20, 'life_H2': 20,
        'life_FC': 10, 'life_EL': 15, 'life_DG': 15,
    }
    
    system = HybridEnergySystem(parameters)
    
    # Base configuration
    base_config = {
        'N_PV': 596,
        'N_WT': 49,
        'N_H2': 59,   # varied below
        'N_FC': 2,
        'N_EL': 2,
        'N_DG': 1,
    }
    
    # Load data
    try:
        data = pd.read_excel(file_path)
    except FileNotFoundError:
        try:
            data = pd.read_excel('data/combined.xlsx')
        except FileNotFoundError:
            print("Error: No data file found!")
            return None

    # Number of H2 storage units to sweep (total capacity = N_H2 * Cap_H2 kg)
    n_h2_values = [10, 20, 30, 40, 50, 75, 100]

    print(f"\n{'N_H2':>8} | {'H2 Cap (kg)':>12} | {'Cost ($/yr)':>13} | {'Emissions (kg CO2)':>18} | {'LPSP (%)':>9}")
    print("-" * 75)
    
    results = []
    for n_h2 in n_h2_values:
        config = base_config.copy()
        config['N_H2'] = n_h2  # vary the number of H2 units in the config

        total_h2_kg = n_h2 * system.Cap_H2

        C_total, E_total, LPSP, details = system.simulate_year(config, data)
        results.append((n_h2, total_h2_kg, C_total, E_total, LPSP))
        
        print(f"{n_h2:>8} | {total_h2_kg:>12.1f} | {C_total:>13,.0f} | {E_total:>18,.0f} | {LPSP*100:>9.3f}")
    
    return results


if __name__ == "__main__":

    file_path = '/kaggle/input/datasets/feyddautha/jimsttttttttttttt/semi_final_load.xlsx'


    # =========================================================================
    # LOAD DATA
    # =========================================================================
    try:
        data = pd.read_excel(file_path)
        print("\n" + "="*80)
        print("DATA LOADED")
        print("="*80)
        print(f"  Source: {file_path}")
    except FileNotFoundError:
        try:
            print("Trying Alternative combined")
            data = pd.read_excel('data/combined.xlsx')
            print("\n" + "="*80)
            print("DATA LOADED")
            print("="*80)
            print(f"  Source: data/combined.xlsx")
        except FileNotFoundError:
            print("\n" + "="*80)
            print("ERROR: Could not load data file!")
            print("="*80)
            print("Please ensure one of the following exists:")
            print(f"  - {file_path}")
            print("  - data/combined.xlsx")


        
    # =========================================================================
    # DEFINE CORRECTED SYSTEM PARAMETERS
    # =========================================================================

#     parameters = {
#     # =================================================================
#     # GENERATOR CONFIGS
#     # =================================================================
#     'rated_PV': 0.327,          # kW - rated power per PV panel
#     'v_cut_in': 2.75,           # m/s - cut-in wind speed
#     'v_rated': 9.0,             # m/s - rated wind speed
#     'rated_power': 25.0,        # kW - wind turbine rated power
#     'Cap_H2': 6,                # kg - capacity of 1 H2 storage unit
#     'Cap_FC': 2,                # kW - rated power per fuel cell unit
#     'Cap_EL': 2,                # kW - rated power per electrolyzer unit
#     'Cap_DG': 3,                # kW - rated power per diesel generator unit
#     'H_min_percentage': 0,      # fraction - minimum H2 storage level (0 = 0%)
#     'H_max_percentage': 0,      # fraction - maximum H2 storage level override

#     # =================================================================
#     # DIESEL CONSTANTS
#     # =================================================================
#     'f_0': 0.246,               # litre/kW/h - diesel curve intercept coefficient
#     'f_1': 0.08145,             # litre/kWh  - diesel curve slope coefficient

#     # =================================================================
#     # EFFICIENCY PARAMETERS
#     # =================================================================
#     'eta_PV': 0.15,             # fraction - PV panel efficiency (15%)
#     'eta_FC': 0.50,             # fraction - fuel cell efficiency (50%)
#     'eta_EL': 0.70,             # fraction - electrolyzer efficiency (70%)
#     'eta_INVT': 0.90,           # fraction - inverter efficiency (90%)
#     'H2_LHV': 33.3,             # kWh/kg   - hydrogen lower heating value

#     # =================================================================
#     # CAPITAL COSTS
#     # =================================================================
#     'c_PV': 1500,               # $/kW     - PV capital cost
#     'c_WT': 3000,               # $/kW     - wind turbine capital cost
#     'c_H2': 500,                # $/kg     - hydrogen storage capital cost
#     'c_FC_cap': 2000,           # $/kW     - fuel cell capital cost
#     'c_EL_cap': 1500,           # $/kW     - electrolyzer capital cost
#     'c_DG_cap': 400,            # $/kW     - diesel generator capital cost
#     'c_INVT': 300,              # $        - inverter capital cost (flat, not per-kW)

#     # =================================================================
#     # OPERATING COSTS
#     # =================================================================
#     'c_FC': 0,                  # $/kWh    - fuel cell operating cost per kWh produced
#     'c_DG': 0,                  # $/kWh    - diesel operating cost per kWh produced
#     'c_EL': 0,                  # $/kWh    - electrolyzer operating cost per kWh consumed
#     'c_DG_FUEL': 0.82,          # $/litre  - diesel fuel cost

#     # =================================================================
#     # O&M COSTS
#     # =================================================================
#     'om_PV': 20,                # $/kW/year  - PV O&M
#     'om_WT': 50,                # $/kW/year  - wind turbine O&M
#     'om_H2': 10,                # $/kg/year  - hydrogen storage O&M
#     'om_FC': 30,                # $/kW/year  - fuel cell O&M
#     'om_EL': 25,                # $/kW/year  - electrolyzer O&M
#     'om_DG': 0.03,              # $/h        - diesel generator O&M (per operating hour)
#     'om_INVT': 0,               # $          - inverter O&M

#     # =================================================================
#     # REPLACEMENT COSTS
#     # =================================================================
#     'rc_PV': 0,                 # $/kW  - PV replacement cost
#     'rc_WT': 1750,              # $/kW  - wind turbine replacement cost
#     'rc_H2': 10,                # $/kg  - hydrogen storage replacement cost
#     'rc_FC': 30,                # $/kW  - fuel cell replacement cost
#     'rc_EL': 25,                # $/kW  - electrolyzer replacement cost
#     'rc_DG': 500,               # $/kW  - diesel generator replacement cost
#     'rc_INVT': 300,             # $     - inverter replacement cost (flat, per unit)

#     # =================================================================
#     # EMISSION FACTORS
#     # =================================================================
#     'e_FC': 0.0,                # kg CO2/kWh    - fuel cell emissions (green H2 = 0)
#     'e_DG': 2.6391,             # kg CO2/litre  - diesel generator emissions
#     'e_EL': 0.0,                # kg CO2/kWh    - electrolyzer direct emissions

#     # =================================================================
#     # ECONOMIC PARAMETERS
#     # =================================================================
#     'T_life': 20,               # years    - project lifetime
#     'r': 0.05,                  # fraction - annual discount rate (5%)
#     'p_grid': 0.08,             # $/kWh    - grid energy selling price

#     # =================================================================
#     # TECHNICAL PARAMETERS
#     # =================================================================
#     'A_PV': 6.67,               # m²/kW   - PV area per kW capacity
#     'P_DG_min': 0.3,            # fraction - minimum diesel generator load ratio (30%)

#     # =================================================================
#     # COMPONENT LIFETIMES
#     # =================================================================
#     'life_PV': 25,              # years - PV panel lifetime
#     'life_WT': 20,              # years - wind turbine lifetime
#     'life_H2': 20,              # years - hydrogen storage lifetime
#     'life_FC': 10,              # years - fuel cell lifetime
#     'life_EL': 15,              # years - electrolyzer lifetime
#     'life_DG': 15,              # years - diesel generator lifetime
#     'life_INVT': 15,            # years - inverter lifetime

#     'output_simulation' : True
# }

    parameters = {
    'rated_PV': 0.327, 'v_cut_in': 2.75, 'v_rated': 9.0, 'rated_power': 25.0,
    'Cap_H2': 100, 'Cap_FC': 100, 'Cap_EL': 100, 'Cap_DG': 3,
    'H_min_percentage': 0, 'H_max_percentage': 0,
    'f_0': 0.246, 'f_1': 0.08145,
    'eta_PV': 0.15, 'eta_FC': 0.50, 'eta_EL': 0.70, 'eta_INVT': 0.90, 'H2_LHV': 33.3,
    'c_PV': 1500, 'c_WT': 3000,
    'c_H2':     300,
    'c_FC_cap': 1200,
    'c_EL_cap': 1000,
    'c_DG_cap': 400, 'c_INVT': 300,
    'c_FC': 0, 'c_DG': 0, 'c_EL': 0, 'c_DG_FUEL': 0.82,
    'om_PV': 20, 'om_WT': 50, 'om_H2': 10, 'om_FC': 30, 'om_EL': 25,
    'om_DG': 0.03, 'om_INVT': 0,
    'rc_PV': 0, 'rc_WT': 1750, 'rc_H2': 10, 'rc_FC': 30, 'rc_EL': 25,
    'rc_DG': 500, 'rc_INVT': 300,
    'e_FC': 0.0, 'e_DG': 2.6391, 'e_EL': 0.0,
    'T_life': 25, 'r': 0.05, 'p_grid': 0.08,
    'A_PV': 6.67, 'P_DG_min': 0.3,
    'life_PV': 25, 'life_WT': 20, 'life_H2': 20, 'life_FC': 10,
    'life_EL': 15, 'life_DG': 15, 'life_INVT': 15,
        
    'output_simulatuion':True
}
        
    
    # =========================================================================
    # DEFINE SYSTEM CONFIGURATION    N_PV= 600  N_WT= 50  N_H2=142  N_FC= 43  N_EL= 49  N_DG= 20
    # =========================================================================
    
    config = {'N_PV': 1974, 'N_WT': 17, 'N_H2': 1, 'N_FC': 1, 'N_EL': 1, 'N_DG': 43}
    #N_PV= 600  N_WT= 47  N_H2= 46  N_FC=  1  N_EL=  2  N_DG= 20
    # Run single simulation
    result = run_single_simulation(data,parameters,config)
    
    if result is not None:
        C_total, E_total, LPSP, system, config, data, details = result
        
        # Create plots — pass system so plot_results can access capacities
        plot_results(details, config, system)
        
        # Uncomment to run sensitivity analysis
        # sensitivity_results = sensitivity_analysis()
# Out:
# ================================================================================
# DATA LOADED
# ================================================================================
#   Source: /kaggle/input/datasets/feyddautha/jimsttttttttttttt/semi_final_load.xlsx
# ================================================================================
# CORRECTED HYBRID ENERGY SYSTEM SIMULATION
# ================================================================================
#
# ================================================================================
# SYSTEM CONFIGURATION
# ================================================================================
#   PV Capacity: RatedPV 0.327kW              1974 panels  ->    645.50 kW
#   Wind Turbine Capacity: Rated Power 25.0kW      17 turbines ->    425.00 kW
#   H2 Storage Capacity: CapH2  100kg         1 units   ->    100.00 kg
#   Fuel Cell Capacity: CapFC  100kW          1 units   ->    100.00 kW
#   Electrolyzer Capacity: CapEL  100kW       1 units   ->    100.00 kW
#   Diesel Generator: CapDG    3kW           43 units   ->    129.00 kW
#
# ================================================================================
# EFFICIENCY DETAILS
# ================================================================================
#   PV Efficiency:              15.0 %
#   Fuel Cell Efficiency:       50.0 %
#   Electrolyzer Efficiency:    70.0 %
#   Inverter Efficiency:        90.0 %
#   H2 Lower Heating Value:     33.3 kWh/kg
#
#   FC Output:                 16.65 kWh per kg H2
#   EL Input Required:         47.57 kWh per kg H2
#   Round-trip Efficiency:      35.0 %
#   Data Points:                  8760 hours
#   Represents:                  365.0 days
#
# ================================================================================
# RUNNING SIMULATION...
# ================================================================================
#
# ================================================================================
# SIMULATION RESULTS
# ================================================================================
#
# --- ECONOMIC PERFORMANCE ---
#   Total Annualized Cost:    $  270,883.72 /year
#   Capital Cost:             $2,545,147.00
#   Replacement Cost:         $  316,033.30
#   Annual O&M Cost:          $   40,692.25 /year
#   Annual Operating Cost:    $   27,183.70 /year
#   Capital Recovery Factor:      0.070952
#
# --- ENVIRONMENTAL PERFORMANCE ---
#   Total Annual Emissions:     166,586.67 kg CO2/year
#   Emission Intensity:           151.8640 g CO2/kWh
#
# --- RELIABILITY PERFORMANCE ---
#   Loss of Power Supply:           0.6294 %
#   Reliability:                   99.3706 %
#   Unmet Energy:                 6,903.70 kWh/year
#
# --- GENERATION (What Was Produced) ---
#   Total Generation:         1,640,587.87 kWh/year  (100.0%)
#   - Renewable Subtotal:    1,431,263.97 kWh/year  ( 87.2%)
#       - PV:                  854,014.68 kWh/year  ( 52.1%)
#       - Wind:                577,249.29 kWh/year  ( 35.2%)
#   - Fuel Cell:                70,484.09 kWh/year  (  4.3%)
#   - Diesel Generator:        138,839.81 kWh/year  (  8.5%)
#
# --- GENERATION ROUTING (Where Did It Go) ---
#   Total Generated:          1,640,587.87 kWh/year
#   - Served Load:           1,090,042.77 kWh/year  ( 66.4%)
#   - Spilled to Grid:         307,209.68 kWh/year  ( 18.7%)
#   - Electrolyzer Input:      243,335.42 kWh/year  ( 14.8%)
#
# --- LOAD BREAKDOWN (What the Load Actually Received) ---
#   Total Load Demand:        1,096,946.47 kWh/year  (100.0%)
#   - Served:                1,090,042.77 kWh/year  ( 99.4%)
#       - From Renewables:     880,718.86 kWh/year  ( 80.8% of served)
#       - From Non-RE:         209,323.90 kWh/year  ( 19.2% of served)
#           - From Diesel:     138,839.81 kWh/year  ( 12.7% of served)
#           - From FC:          70,484.09 kWh/year  (  6.5% of served)
#   - Unmet:                     6,903.70 kWh/year  (  0.6%)
#
# --- RENEWABLE FRACTION (Three Ways to Measure) ---
#   RE Generated / Load:            130.48 %  <- inflated (counts spilled RE)
#   RE Generated / Total Gen:        87.24 %  <- pie chart number
#   RE Consumed / Load Served:       80.80 %  <- most honest
#
# --- COST & PERFORMANCE SUMMARY ---
#   Levelized Cost (LCOE):    $      0.2485 /kWh
#
# --- CAPITAL COST BREAKDOWN ---
#   Total Capital Cost:       $2,545,147.00  (100.0%)
#   - PV System:             $  968,247.00  ( 38.0%)
#   - Wind Turbines:         $1,275,000.00  ( 50.1%)
#   - H2 Storage:            $   30,000.00  (  1.2%)
#   - Fuel Cell:             $  120,000.00  (  4.7%)
#   - Electrolyzer:          $  100,000.00  (  3.9%)
#   - Diesel Generator:      $   51,600.00  (  2.0%)
#
# ================================================================================
#
# Plot saved to: simulation_results_cutin2.75.png

# %%
"""
NSGA-II Optimization for Hybrid Energy System
==============================================
Paste this file next to your HybridEnergySystem file and run:
    python nsga2_optimizer.py

Optimizes: N_PV, N_WT, N_H2, N_FC, N_EL, N_DG
"""

import numpy as np
import pandas as pd
import random
import time
import warnings
from typing import Dict, List, Tuple, Optional
# AFTER the existing imports, add:
from multiprocessing import Pool
import os

warnings.filterwarnings('ignore')

# ============================================================
# IMPORT YOUR SIMULATION  (adjust path if needed)
# ============================================================


# ============================================================
# ██████╗  ██████╗ ███╗   ██╗███████╗██╗ ██████╗
# ██╔════╝██╔═══██╗████╗  ██║██╔════╝██║██╔════╝
# ██║     ██║   ██║██╔██╗ ██║█████╗  ██║██║  ███╗
# ██║     ██║   ██║██║╚██╗██║██╔══╝  ██║██║   ██║
# ╚██████╗╚██████╔╝██║ ╚████║██║     ██║╚██████╔╝
#  ╚═════╝ ╚═════╝ ╚═╝  ╚═══╝╚═╝     ╚═╝ ╚═════╝
# ============================================================

# ------------------------------------------------------------
# SECTION 1: DECISION VARIABLE BOUNDS
# [min, max] integer range for each component
# ------------------------------------------------------------
BOUNDS = {
    'N_PV': (0,  0),
    'N_WT': (1,  4000),
    'N_H2': (1,  6000),
    'N_FC': (1,  1500),
    'N_EL': (1,  1500),
    'N_DG': (1,   300),
}

# ------------------------------------------------------------
# SECTION 2: OBJECTIVES
# ------------------------------------------------------------
OBJECTIVES = [
    ('Cost',      'C_total', 'minimize'),
    ('Emissions', 'E_total', 'minimize'),
]

# ------------------------------------------------------------
# SECTION 3: CONSTRAINTS
# ------------------------------------------------------------
CONSTRAINTS = [
    ('reliability',   'LPSP',    '<=',.015),
    ('diesel_fraction','diesel_fraction','<=',0.10),
    ('spilled_fraction','spilled_fraction',"<=",0.18)
]

# ------------------------------------------------------------
# SECTION 4: GA PARAMETERS
# ------------------------------------------------------------

POP_SIZE       = 20
N_GENERATIONS  = 500
CROSSOVER_PROB = 0.9
MUTATION_PROB  = 0.1
TOURNAMENT_K   = 3
RANDOM_SEED    = 42
PRINT_EVERY    = 10
VERBOSE_TABLE = False
# ------------------------------------------------------------
# SECTION 5: OUTPUT FILES
# ------------------------------------------------------------
PARETO_CSV  = '/kaggle/working/pareto_front.csv'
HISTORY_CSV = '/kaggle/working/optimization_history.csv'


# ------------------------------------------------------------
# SECTION 6: CUSTOM OBJECTIVE  (optional)
# ------------------------------------------------------------
CUSTOM_OBJECTIVE_FN = None

# ------------------------------------------------------------
# SECTION 7: CUSTOM CONSTRAINT  (optional)
# ------------------------------------------------------------
def custom_constraint(config_dict, C_total, E_total, LPSP, details):
    """
    Equation   : E_nonRE_consumed / E_consumed <= 0.10
    Variables  : E_RE_generated  = E_PV + E_WT  (kWh/year)
                 E_RE_consumed   = E_RE_generated - E_spilled - E_EL
                                   (renewable energy that actually reached the load)
                 E_consumed      = L_year - E_unmet
                                   (total load actually served, kWh/year)
                 E_nonRE_consumed = E_consumed - E_RE_consumed
                                   (FC + DG share of served load, kWh/year)
    Meaning    : Non-renewable sources (FC + DG combined) must supply
                 no more than 10% of the load actually served.
                 RE spilled to grid and electrolyzer input are excluded
                 from RE_consumed since they never reached the load.
    Violation  : max(0, E_nonRE_consumed / E_consumed - 0.10)
                 0.00 = fully satisfied (non-RE <= 10% of served load)
                 0.05 = non-RE is at 15% of served load (5pp over limit)
    """
    E_PV        = details.get('E_PV_total', 0)
    E_WT        = details.get('E_WT_total', 0)
    E_EL        = details.get('E_EL_total', 0)
    E_DG        = details.get('E_DG_total', 0)
    E_spilled   = details.get('E_grid', 0)
    L_year      = details.get('L_year', 1) or 1
    E_unmet     = details.get('E_unmet', 0)

    E_RE_generated   = E_PV + E_WT
    E_RE_consumed    = max(0.0, E_RE_generated - E_spilled - E_EL)
    E_consumed       = max(1.0, L_year - E_unmet)
    E_nonRE_consumed = max(0.0, E_consumed - E_RE_consumed)

    return max(0.0, E_nonRE_consumed / E_consumed - 0.50)


def custom_constraint_LCOE(config_dict, C_total, E_total, LPSP, details):
    """
    LCOE
    """
    E_PV        = details.get('E_PV_total', 0)
    E_WT        = details.get('E_WT_total', 0)
    E_EL        = details.get('E_EL_total', 0)
    E_DG        = details.get('E_DG_total', 0)
    E_spilled   = details.get('E_grid', 0)
    L_year      = details.get('L_year', 1) or 1
    E_unmet     = details.get('E_unmet', 0)
    
    

    LCOE        =  C_total / (L_year-E_unmet)
    LCOE = C_total / (L_year - E_unmet)
    return max(0.0, LCOE - 0.40)

# CUSTOM_CONSTRAINT_FN = custom_constraint

CUSTOM_CONSTRAINT_FN = custom_constraint_LCOE


# ============================================================
# INTERNALS
# ============================================================

GENE_NAMES = list(BOUNDS.keys())
N_VAR  = len(GENE_NAMES)
N_OBJ  = len(OBJECTIVES) + (1 if CUSTOM_OBJECTIVE_FN else 0)
N_CON  = len(CONSTRAINTS) + (1 if CUSTOM_CONSTRAINT_FN else 0)
LB = np.array([BOUNDS[k][0] for k in GENE_NAMES], dtype=float)
UB = np.array([BOUNDS[k][1] for k in GENE_NAMES], dtype=float)
OBJ_DIR = np.array([1.0 if d == 'minimize' else -1.0 for _, _, d in OBJECTIVES])


# ============================================================
# INDIVIDUAL
# ============================================================

class Individual:
    def __init__(self, genes: np.ndarray):
        self.genes             = genes.copy()
        self.objectives        = None
        self.constraints       = None
        self.rank              = 0
        self.crowding_distance = 0.0
        self.feasible          = True   # DEBUG NOTE: initialised TRUE — never reset before evaluate()

    def copy(self):
        ind = Individual(self.genes)
        if self.objectives  is not None: ind.objectives  = self.objectives.copy()
        if self.constraints is not None: ind.constraints = self.constraints.copy()
        ind.rank              = self.rank
        ind.crowding_distance = self.crowding_distance
        ind.feasible          = self.feasible   # DEBUG NOTE: copies parent feasible flag into child
        return ind

    def to_config(self) -> Dict:
        return {name: int(self.genes[i]) for i, name in enumerate(GENE_NAMES)}


# ============================================================
# EVALUATION
# ============================================================

def evaluate(ind: Individual, sim: 'HybridEnergySystem', data: pd.DataFrame) -> Individual:
    cfg = ind.to_config()

    # DEBUG: capture feasible flag coming IN (before evaluation)
    feasible_before = ind.feasible

    try:
        C_total, E_total, LPSP, details = sim.simulate_year(cfg, data)
    except Exception as e:
        print(f"EVAL FAILED: {cfg}")
        print(f"ERROR: {e}")
        import traceback
        traceback.print_exc()
        ind.objectives  = np.full(N_OBJ, 1e12)
        ind.constraints = np.full(max(N_CON, 1), 1e12)
        ind.feasible    = False
        return ind

    L    = details.get('L_year', 1) or 1
    E_re = details.get('E_PV_total', 0) + details.get('E_WT_total', 0)
    E_spilled = details.get('E_grid', 0)
    metrics = {
        'C_total': C_total, 'E_total': E_total, 'LPSP': LPSP,
        'renewable_fraction': max(0.0, E_re - E_spilled - details.get('E_EL_total', 0))
                              / max(1.0, L - details.get('E_unmet', 0)),
        'diesel_fraction' : max(0.0, details.get('E_DG_total',0))/ max(1.0, E_re + details.get('E_FC_total')+details.get('E_DG_total')),
        **{k: v for k, v in details.items() if np.isscalar(v)},
        'spilled_fraction': E_spilled/(E_re + details.get('E_FC_total')+details.get('E_DG_total')),
    }

    obj_vals = [float(metrics.get(m, 0.0)) for _, m, _ in OBJECTIVES]
    if CUSTOM_OBJECTIVE_FN is not None:
        extra = CUSTOM_OBJECTIVE_FN(cfg, C_total, E_total, LPSP, details)
        obj_vals += [extra] if np.isscalar(extra) else list(extra)
    ind.objectives = np.array(obj_vals)

    con_vals = []
    for _, m, op, limit in CONSTRAINTS:
        v = float(metrics.get(m, 0.0))
        if   op == '<=': con_vals.append(max(0.0, v - limit))
        elif op == '>=': con_vals.append(max(0.0, limit - v))
        elif op == '<' : con_vals.append(max(0.0, v - limit + 1e-9))
        elif op == '>' : con_vals.append(max(0.0, limit - v + 1e-9))
        elif op == '==': con_vals.append(abs(v - limit))

    # DEBUG: capture raw constraint values BEFORE custom constraint is added
    con_vals_before_custom = con_vals.copy()

    if CUSTOM_CONSTRAINT_FN is not None:
        extra = CUSTOM_CONSTRAINT_FN(cfg, C_total, E_total, LPSP, details)
        con_vals += [extra] if np.isscalar(extra) else list(extra)

    ind.constraints = np.array(con_vals) if con_vals else np.zeros(1)
    ind.feasible    = bool(np.all(ind.constraints <= 1e-9))

    # DEBUG: print every individual that has a mismatch between
    # LPSP constraint alone vs final feasible flag
    lpsp_viol = con_vals_before_custom[0] if con_vals_before_custom else 0.0
    lpsp_alone_feasible = (lpsp_viol <= 1e-9)
    custom_viol = con_vals[-1] if CUSTOM_CONSTRAINT_FN is not None else 0.0
    if lpsp_alone_feasible != ind.feasible:
        print(
            f"  [DEBUG EVAL MISMATCH] cfg={cfg} | "
            f"LPSP={LPSP:.6f} lpsp_viol={lpsp_viol:.6e} lpsp_alone_feasible={lpsp_alone_feasible} | "
            f"custom_viol={custom_viol:.6e} | "
            f"final_feasible={ind.feasible} | "
            f"feasible_before_eval={feasible_before}"
        )

    return ind


# ============================================================
# NSGA-II OPERATORS
# ============================================================

def dominates(a: Individual, b: Individual) -> bool:
    a_viol = float(np.sum(np.maximum(a.constraints, 0)))
    b_viol = float(np.sum(np.maximum(b.constraints, 0)))
    if     a.feasible and not b.feasible: return True
    if not a.feasible and     b.feasible: return False
    if not a.feasible and not b.feasible: return a_viol < b_viol
    a_obj = a.objectives * OBJ_DIR
    b_obj = b.objectives * OBJ_DIR
    return bool(np.all(a_obj <= b_obj) and np.any(a_obj < b_obj))


def fast_nondominated_sort(pop: List[Individual]) -> List[List[int]]:
    n  = len(pop)
    S  = [[] for _ in range(n)]
    nd = [0] * n
    fronts = [[]]
    for i in range(n):
        for j in range(n):
            if i == j: continue
            if   dominates(pop[i], pop[j]): S[i].append(j)
            elif dominates(pop[j], pop[i]): nd[i] += 1
        if nd[i] == 0:
            pop[i].rank = 0
            fronts[0].append(i)
    f = 0
    while fronts[f]:
        nxt = []
        for i in fronts[f]:
            for j in S[i]:
                nd[j] -= 1
                if nd[j] == 0:
                    pop[j].rank = f + 1
                    nxt.append(j)
        f += 1
        fronts.append(nxt)
    return [x for x in fronts if x]


def assign_crowding(pop: List[Individual], fronts: List[List[int]]):
    for front in fronts:
        if len(front) <= 2:
            for i in front: pop[i].crowding_distance = float('inf')
            continue
        for i in front: pop[i].crowding_distance = 0.0
        for oi in range(N_OBJ):
            srt  = sorted(front, key=lambda i: pop[i].objectives[oi])
            vals = [pop[i].objectives[oi] for i in srt]
            rng  = vals[-1] - vals[0]
            pop[srt[0]].crowding_distance  = float('inf')
            pop[srt[-1]].crowding_distance = float('inf')
            if rng < 1e-10: continue
            for k in range(1, len(srt) - 1):
                pop[srt[k]].crowding_distance += (vals[k+1] - vals[k-1]) / rng


def tournament(pop: List[Individual]) -> Individual:
    cands = random.sample(pop, TOURNAMENT_K)
    best  = cands[0]
    for c in cands[1:]:
        if c.rank < best.rank or (c.rank == best.rank and c.crowding_distance > best.crowding_distance):
            best = c
    return best


def sbx_crossover(p1: Individual, p2: Individual) -> Tuple[Individual, Individual]:
    eta = 15.0
    c1, c2 = p1.copy(), p2.copy()
    for i in range(N_VAR):
        if random.random() > 0.5: continue
        x1, x2 = float(p1.genes[i]), float(p2.genes[i])
        if abs(x1 - x2) < 1e-10: continue
        xl, xu = LB[i], UB[i]
        u = random.random()
        b = (2*u)**(1/(eta+1)) if u <= 0.5 else (1/(2*(1-u)))**(1/(eta+1))
        c1.genes[i] = int(np.clip(round(0.5*((x1+x2) - b*abs(x2-x1))), xl, xu))
        c2.genes[i] = int(np.clip(round(0.5*((x1+x2) + b*abs(x2-x1))), xl, xu))
    return c1, c2


def poly_mutation(ind: Individual) -> Individual:
    eta   = 20.0
    child = ind.copy()
    for i in range(N_VAR):
        if random.random() > MUTATION_PROB: continue
        xl, xu = LB[i], UB[i]
        if xl >= xu: continue
        x   = float(child.genes[i])
        rng = xu - xl
        d   = min(x - xl, xu - x) / rng
        u   = random.random()
        dq  = (2*u + (1-2*u)*(1-d)**(eta+1))**(1/(eta+1)) - 1 if u <= 0.5 \
              else 1 - (2*(1-u) + 2*(u-0.5)*(1-d)**(eta+1))**(1/(eta+1))
        child.genes[i] = int(np.clip(round(x + dq*rng), xl, xu))
    return child


# ============================================================
# DEBUG HELPER
# ============================================================
def debug_feasibility_report(pop: List[Individual], label: str):
    n_total    = len(pop)
    n_feasible = sum(1 for ind in pop if ind.feasible)
    n_rank0    = sum(1 for ind in pop if ind.rank == 0)
    n_rank0_feasible   = sum(1 for ind in pop if ind.rank == 0 and ind.feasible)
    n_rank0_infeasible = sum(1 for ind in pop if ind.rank == 0 and not ind.feasible)

    con_labels = [lbl for lbl, _, _, _ in CONSTRAINTS]
    if CUSTOM_CONSTRAINT_FN is not None:
        con_labels.append('custom')

    print(f"\n  {'='*61}")
    print(f"  [DEBUG FEASIBILITY REPORT] {label}")
    print(f"  {'='*61}")
    print(f"  Total pop       : {n_total}")
    print(f"  Feasible        : {n_feasible}  /  {n_total}")
    print(f"  Infeasible      : {n_total - n_feasible}  /  {n_total}")
    print(f"  Rank-0 total    : {n_rank0}")
    print(f"  Rank-0 feasible : {n_rank0_feasible}")
    print(f"  Rank-0 infeasible:{n_rank0_infeasible}")

    # ── optional per-individual table ─────────────────────────────
    if VERBOSE_TABLE:
        print(f"  {'-'*61}")
        print(f"  {'#':>3}  {'rank':>4}  {'feasible':>8}  {'obj[0](Cost)':>14}  {'obj[1](Emis)':>14}  " +
              "  ".join(f"viol_{lbl:>12}" for lbl in con_labels))
        print(f"  {'-'*61}")
        for i, ind in enumerate(pop):
            con_str = "  ".join(f"{ind.constraints[j]:>18.6e}" for j in range(len(con_labels)))
            feasible_str = "TRUE " if ind.feasible else "FALSE"
            recomputed_feasible = bool(np.all(ind.constraints <= 1e-9))
            mismatch = " <-- MISMATCH!" if recomputed_feasible != ind.feasible else ""
            print(f"  {i:>3}  {ind.rank:>4}  {feasible_str:>8}  "
                  f"{ind.objectives[0]:>14.4g}  {ind.objectives[1]:>14.4g}  "
                  f"{con_str}{mismatch}")

    # ── constraint violation stats (always printed) ───────────────
    infeasible_pop = [ind for ind in pop if not ind.feasible]
    if infeasible_pop:
        print(f"  {'-'*61}")
        print(f"  Constraint violation stats (infeasible individuals only):")
        con_arr = np.array([ind.constraints for ind in infeasible_pop])
        for j, lbl in enumerate(con_labels):
            print(f"    viol_{lbl}: min={con_arr[:,j].min():.4e}  "
                  f"max={con_arr[:,j].max():.4e}  "
                  f"mean={con_arr[:,j].mean():.4e}  "
                  f"n_violated={np.sum(con_arr[:,j] > 1e-9)}/{len(infeasible_pop)}")

    feasible_pop = [ind for ind in pop if ind.feasible]
    if feasible_pop:
        print(f"  {'-'*61}")
        print(f"  Constraint violation stats (feasible individuals — should all be ~0):")
        con_arr = np.array([ind.constraints for ind in feasible_pop])
        for j, lbl in enumerate(con_labels):
            flag = " <-- FEASIBLE INDIVIDUALS WITH ACTUAL VIOLATIONS!" if np.any(con_arr[:,j] > 1e-9) else ""
            print(f"    viol_{lbl}: min={con_arr[:,j].min():.4e}  "
                  f"max={con_arr[:,j].max():.4e}  "
                  f"mean={con_arr[:,j].mean():.4e}  "
                  f"n_actually_violated={np.sum(con_arr[:,j] > 1e-9)}/{len(feasible_pop)}{flag}")

    print(f"  {'='*61}\n")

# ============================================================
# MAIN NSGA-II LOOP
# ============================================================

def run_nsga2(sim: 'HybridEnergySystem', data: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
    print('-' * 65)

    # ── STARTUP SUMMARY ───────────────────────────────────────────
    print("\n  OBJECTIVES")
    print(f"  {'Label':<14} {'Metric':<22} {'Direction'}")
    print(f"  {'-'*50}")
    for lbl, metric, direction in OBJECTIVES:
        print(f"  {lbl:<14} {metric:<22} {direction}")

    print("\n  HARD CONSTRAINTS")
    print(f"  {'Label':<14} {'Metric':<18} {'Op':<4} {'Limit':<10} {'Meaning'}")
    print(f"  {'-'*65}")
    constraint_meanings = {
        'LPSP':  'Loss of Power Supply — fraction of load unserved. 0.05 = max 5% unmet energy per year.',
        'LCOE':  'Levelised cost of energy in $/kWh.',
        'C_total': 'Total annualised system cost in $/year.',
        'E_total': 'Total CO2 emissions in kg/year.',
    }
    for lbl, metric, op, limit in CONSTRAINTS:
        meaning = constraint_meanings.get(metric, metric)
        print(f"  {lbl:<14} {metric:<18} {op:<4} {str(limit):<10} {meaning}")

    if CUSTOM_CONSTRAINT_FN is not None:
        import inspect
        doc = inspect.getdoc(CUSTOM_CONSTRAINT_FN) or "No docstring provided."
        print("\n  CUSTOM CONSTRAINT  (function: custom_constraint)")
        print(f"  {'─'*65}")
        for line in doc.splitlines():
            print(f"  {line}")

    print(f"\n  DECISION VARIABLES")
    print(f"  {'Variable':<10} {'Min':>6} {'Max':>6}  {'Meaning'}")
    print(f"  {'-'*55}")
    var_meanings = {
        'N_PV':  'Number of PV panels',
        'N_WT':  'Number of wind turbines',
        'N_H2':  'Number of H2 storage units',
        'N_FC':  'Number of fuel cell units',
        'N_EL':  'Number of electrolyzer units',
        'N_DG':  'Number of diesel generator units',
    }
    for var, (lo, hi) in BOUNDS.items():
        print(f"  {var:<10} {lo:>6} {hi:>6}  {var_meanings.get(var, '')}")

    print(f"\n  VERBOSE_TABLE = {VERBOSE_TABLE}  "
          f"({'per-individual table printed every ' + str(PRINT_EVERY) + ' gens' if VERBOSE_TABLE else 'set VERBOSE_TABLE=True to enable per-individual breakdown'})")
    print('=' * 65)
    # ── END STARTUP SUMMARY ───────────────────────────────────────

    if RANDOM_SEED is not None:
        np.random.seed(RANDOM_SEED)
        random.seed(RANDOM_SEED)

    t0 = time.time()
    print('=' * 65)
    print('  NSGA-II  —  Hybrid Energy System Optimizer')
    print('=' * 65)
    print(f"  Pop: {POP_SIZE}  |  Generations: {N_GENERATIONS}  |  Seed: {RANDOM_SEED}")
    print(f"  Objectives : {[lbl for lbl,_,_ in OBJECTIVES]}")
    print(f"  Constraints: {[lbl for lbl,_,_,_ in CONSTRAINTS]}")
    print(f"  N_CON (including custom): {N_CON}")   # DEBUG
    print('-' * 65)

    # Initialize
    pop = [
        Individual(np.array([random.randint(int(LB[i]), int(UB[i])) for i in range(N_VAR)], dtype=float))
        for _ in range(POP_SIZE)
    ]

    # DEBUG: show feasible flag state before any evaluation
    print(f"  [DEBUG] Initial pop feasible flags before evaluate(): "
          f"{[ind.feasible for ind in pop]}")

    with Pool(processes=os.cpu_count()) as pool:
        results = pool.starmap(evaluate, [(ind, sim, data) for ind in pop])
    pop = results

    # DEBUG: show feasible flags immediately after initial evaluation
    print(f"  [DEBUG] Initial pop feasible flags AFTER evaluate(): "
          f"{[ind.feasible for ind in pop]}")
    print(f"  [DEBUG] Initial pop constraint arrays:")
    for i, ind in enumerate(pop):
        print(f"    ind[{i:>2}] constraints={np.array2string(ind.constraints, precision=4, separator=', ')}"
              f"  feasible={ind.feasible}")

    fronts = fast_nondominated_sort(pop)
    assign_crowding(pop, fronts)

    history = []

    for gen in range(N_GENERATIONS):

        # Offspring
        offspring = []
        while len(offspring) < POP_SIZE:
            p1, p2 = tournament(pop), tournament(pop)
            c1, c2 = sbx_crossover(p1, p2) if random.random() < CROSSOVER_PROB else (p1.copy(), p2.copy())
            for c in (c1, c2):
                c = poly_mutation(c)
                # DEBUG NOTE: c.feasible is NOT reset here — it inherits parent's flag
                # This is intentional (no fix) — just logging it
                c.objectives = c.constraints = None
                offspring.append(c)
        offspring = offspring[:POP_SIZE]

        # DEBUG: show how many offspring have stale feasible=True before evaluation
        stale_true  = sum(1 for o in offspring if o.feasible is True)
        stale_false = sum(1 for o in offspring if o.feasible is False)
        # (we expect all True since copy() propagates parent flag and __init__ defaults to True)

        with Pool(processes=os.cpu_count()) as pool:
            results = pool.starmap(evaluate, [(ind, sim, data) for ind in offspring])
        offspring = results

        # Combine, sort, select
        combined = pop + offspring
        fronts   = fast_nondominated_sort(combined)
        assign_crowding(combined, fronts)

        # DEBUG: snapshot feasibility in COMBINED before truncation
        n_combined_feasible   = sum(1 for ind in combined if ind.feasible)
        n_combined_infeasible = sum(1 for ind in combined if not ind.feasible)
        n_combined_rank0_feas = sum(1 for ind in combined if ind.rank == 0 and ind.feasible)

        pop = []
        for front in fronts:
            if len(pop) + len(front) <= POP_SIZE:
                pop += [combined[i] for i in front]
            else:
                remaining = POP_SIZE - len(pop)
                srt = sorted(front, key=lambda i: combined[i].crowding_distance, reverse=True)
                pop += [combined[i] for i in srt[:remaining]]
                break

        # DEBUG: snapshot feasibility in POP after truncation
        n_pop_feasible   = sum(1 for ind in pop if ind.feasible)
        n_pop_infeasible = sum(1 for ind in pop if not ind.feasible)
        n_pop_rank0_feas = sum(1 for ind in pop if ind.rank == 0 and ind.feasible)
        n_pop_rank0_inf  = sum(1 for ind in pop if ind.rank == 0 and not ind.feasible)

        # Record history
        feasible = [ind for ind in pop if ind.feasible] or pop
        obj_arr  = np.array([ind.objectives for ind in feasible])
        entry    = {'generation': gen + 1, 'n_feasible': len(feasible)}
        for idx, (lbl, _, _) in enumerate(OBJECTIVES):
            entry[f'{lbl}_min']  = float(np.min(obj_arr[:, idx]))
            entry[f'{lbl}_mean'] = float(np.mean(obj_arr[:, idx]))
        history.append(entry)

        if (gen + 1) % PRINT_EVERY == 0:
            mins = '  '.join(f"{entry[f'{lbl}_min']:>12.4g}" for lbl, _, _ in OBJECTIVES)
            print(f"  Gen {gen+1:>4}  |  feasible: {len(feasible):>3}  |  {mins}  |  {time.time()-t0:.0f}s")

            # Print best individual by first objective
            best = min(feasible, key=lambda ind: ind.objectives[0])
            cfg  = best.to_config()
            print(f"    Best: N_PV={cfg['N_PV']:>4}  N_WT={cfg['N_WT']:>3}  N_H2={cfg['N_H2']:>3}  N_FC={cfg['N_FC']:>3}  N_EL={cfg['N_EL']:>3}  N_DG={cfg['N_DG']:>3}"
                f"  ->  " + "  ".join(f"{lbl}={best.objectives[i]:.4g}" for i, (lbl,_,_) in enumerate(OBJECTIVES)))

            # ----------------------------------------------------------------
            # DEBUG: extra info appended to the standard print line
            # ----------------------------------------------------------------
            print(f"    [DEBUG GEN {gen+1}]  offspring stale_feasible_true={stale_true}  stale_feasible_false={stale_false}")
            print(f"    [DEBUG GEN {gen+1}]  COMBINED ({len(combined)}): "
                  f"feasible={n_combined_feasible}  infeasible={n_combined_infeasible}  "
                  f"rank0_feasible={n_combined_rank0_feas}")
            print(f"    [DEBUG GEN {gen+1}]  POP after truncation ({len(pop)}): "
                  f"feasible={n_pop_feasible}  infeasible={n_pop_infeasible}  "
                  f"rank0_feasible={n_pop_rank0_feas}  rank0_infeasible={n_pop_rank0_inf}")
            print(f"    [DEBUG GEN {gen+1}]  history feasible count (used for print above): "
                  f"{len(feasible)}  (fallback to pop? {len([ind for ind in pop if ind.feasible]) == 0})")

            # Full per-individual feasibility report
            debug_feasibility_report(pop, f"Gen {gen+1} — POP after truncation")

    # Extract Pareto front
    pareto = [ind for ind in pop if ind.rank == 0 and ind.feasible]
    if not pareto:
        print("WARNING: No feasible Pareto solutions found; showing best infeasible")
        pareto = [ind for ind in pop if ind.rank == 0]

    # DEBUG: final state before writing CSV
    print(f"\n  [DEBUG FINAL] pop size={len(pop)}")
    print(f"  [DEBUG FINAL] rank-0 total={sum(1 for ind in pop if ind.rank==0)}")
    print(f"  [DEBUG FINAL] rank-0 feasible={sum(1 for ind in pop if ind.rank==0 and ind.feasible)}")
    print(f"  [DEBUG FINAL] rank-0 infeasible={sum(1 for ind in pop if ind.rank==0 and not ind.feasible)}")
    print(f"  [DEBUG FINAL] pareto list used for CSV: {len(pareto)} solutions")
    for i, ind in enumerate(pareto):
        print(f"    pareto[{i}] feasible={ind.feasible}  rank={ind.rank}  "
              f"constraints={np.array2string(ind.constraints, precision=6, separator=', ')}")

    rows = []
    for ind in pareto:
        row = ind.to_config()
        for idx, (lbl, _, _) in enumerate(OBJECTIVES):
            row[lbl] = ind.objectives[idx]
        for idx, (lbl, _, _, _) in enumerate(CONSTRAINTS):
            row[f'viol_{lbl}'] = ind.constraints[idx]
        row['feasible'] = ind.feasible
        rows.append(row)

    pareto_df  = pd.DataFrame(rows)
    history_df = pd.DataFrame(history)
    pareto_df.to_csv(PARETO_CSV,   index=False)
    history_df.to_csv(HISTORY_CSV, index=False)

    print('=' * 65)
    print(f"  Done in {time.time()-t0:.1f}s  |  Pareto solutions: {len(pareto_df)}")
    print(f"  Saved: {PARETO_CSV}  |  {HISTORY_CSV}")
    print('=' * 65)

    return pareto_df, history_df


# ============================================================
# SYSTEM PARAMETERS
# ============================================================







PARAMETERS = {
    'rated_PV': 0.327, 'v_cut_in': 1.8, 'v_rated': 12.0, 'rated_power': 5.0,
    'Cap_H2': 6, 'Cap_FC': 2, 'Cap_EL': 2, 'Cap_DG': 3,
    'H_min_percentage': 0, 'H_max_percentage': 0,
    'f_0': 0.246, 'f_1': 0.0845,
    'eta_PV': 0.204, 'eta_FC': 0.50, 'eta_EL': 0.75, 'eta_INVT': 0.96, 'H2_LHV': 39.72,
    'c_PV': 1300, 'c_WT': 420,
    'c_H2': 660,
    'c_FC_cap': 3000,
    'c_EL_cap': 2000,
    'c_DG_cap': 500, 'c_INVT': 300,
    'c_FC': 0, 'c_DG': 0, 'c_EL': 0, 'c_DG_FUEL': 1.0,
    'om_PV': 20, 'om_WT': 7, 'om_H2': 13.2, 'om_FC': 60, 'om_EL': 10,
    'om_DG': 1.5, 'om_INVT': 0,
    'rc_PV': 0, 'rc_WT': 0, 'rc_H2': 1500, 'rc_FC': 2500, 'rc_EL': 1500,
    'rc_DG': 500, 'rc_INVT': 300,
    'e_FC': 0.0, 'e_DG': 2.6391, 'e_EL': 0.0,
    'T_life': 20, 'r': 0.05, 'p_grid': 0.00,
    'A_PV': 6.67, 'P_DG_min': 0.3,
    'life_PV': 25, 'life_WT': 20, 'life_H2': 20, 'life_FC': 5,
    'life_EL': 15, 'life_DG': 5, 'life_INVT': 15,
}
# ============================================================
# ENTRY POINT
# ============================================================

if __name__ == '__main__':
    print(f"CPU cores available: {os.cpu_count()}")
    version_check = 6942067
    print(f"Hi Jim, if the next->{version_check} number matches the number provided to you,\n this is is the correct version")

    # 1. Load your data
    scaling_factor = 1  # Change this to any value > 1 to scale up, < 1 to scale down
    data['Community Load'] = data['Community Load'] * scaling_factor

    # 2. Instantiate simulation
    sim = HybridEnergySystem(PARAMETERS)

    # 3. Run optimizer
    pareto_df, history_df = run_nsga2(sim, data)

    # 4. Print best per objective
    print("\nBest solution by Cost:")
    print(pareto_df.loc[pareto_df['Cost'].idxmin()])

    print("\nBest solution by Emissions:")
    print(pareto_df.loc[pareto_df['Emissions'].idxmin()])
# Out:
# CPU cores available: 4
# Hi Jim, if the next->6942067 number matches the number provided to you,
#  this is is the correct version
# -----------------------------------------------------------------
#
#   OBJECTIVES
#   Label          Metric                 Direction
#   --------------------------------------------------
#   Cost           C_total                minimize
#   Emissions      E_total                minimize
#
#   HARD CONSTRAINTS
#   Label          Metric             Op   Limit      Meaning
#   -----------------------------------------------------------------
#   reliability    LPSP               <=   0.05       Loss of Power Supply — fraction of load unserved. 0.05 = max 5% unmet energy per year.
#   diesel_fraction diesel_fraction    <=   0.1        diesel_fraction
#
#   CUSTOM CONSTRAINT  (function: custom_constraint)
#   ─────────────────────────────────────────────────────────────────
#   LCOE
#
#   DECISION VARIABLES
#   Variable      Min    Max  Meaning
#   -------------------------------------------------------
#   N_PV            1   6000  Number of PV panels
#   N_WT            1  15000  Number of wind turbines
#   N_H2            1   6000  Number of H2 storage units
#   N_FC            1   1500  Number of fuel cell units
#   N_EL            1   1500  Number of electrolyzer units
#   N_DG            1    300  Number of diesel generator units
#
#   VERBOSE_TABLE = False  (set VERBOSE_TABLE=True to enable per-individual breakdown)
# =================================================================
# =================================================================
#   NSGA-II  —  Hybrid Energy System Optimizer
# =================================================================
#   Pop: 20  |  Generations: 400  |  Seed: 42
#   Objectives : ['Cost', 'Emissions']
#   Constraints: ['reliability', 'diesel_fraction']
#   N_CON (including custom): 3
# -----------------------------------------------------------------
#   [DEBUG] Initial pop feasible flags before evaluate(): [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4838, 'N_WT': 6913, 'N_H2': 261, 'N_FC': 62, 'N_EL': 192, 'N_DG': 112} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.726950e-01 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5239, 'N_WT': 1825, 'N_H2': 205, 'N_FC': 564, 'N_EL': 502, 'N_DG': 115} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.963902e-01 | final_feasible=False | feasible_before_eval=True  [DEBUG EVAL MISMATCH] cfg={'N_PV': 5866, 'N_WT': 10648, 'N_H2': 5746, 'N_FC': 1117, 'N_EL': 860, 'N_DG': 113} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.842442e+00 | final_feasible=False | feasible_before_eval=True
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2788, 'N_WT': 4553, 'N_H2': 1274, 'N_FC': 441, 'N_EL': 690, 'N_DG': 53} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.986009e-01 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 1906, 'N_WT': 8280, 'N_H2': 4932, 'N_FC': 55, 'N_EL': 1150, 'N_DG': 102} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.142067e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 1144, 'N_WT': 12067, 'N_H2': 840, 'N_FC': 1386, 'N_EL': 1117, 'N_DG': 45} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.739701e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 760, 'N_WT': 6225, 'N_H2': 793, 'N_FC': 736, 'N_EL': 705, 'N_DG': 136} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.640465e-01 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3680, 'N_WT': 9655, 'N_H2': 2279, 'N_FC': 14, 'N_EL': 327, 'N_DG': 217} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.009165e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 356, 'N_WT': 11956, 'N_H2': 3764, 'N_FC': 1099, 'N_EL': 256, 'N_DG': 194} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.761258e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4730, 'N_WT': 3151, 'N_H2': 5772, 'N_FC': 143, 'N_EL': 94, 'N_DG': 117} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.180628e-01 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3715, 'N_WT': 10416, 'N_H2': 2989, 'N_FC': 334, 'N_EL': 759, 'N_DG': 182} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.304916e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4991, 'N_WT': 10404, 'N_H2': 1402, 'N_FC': 1094, 'N_EL': 1494, 'N_DG': 126} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.564076e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 646, 'N_WT': 9045, 'N_H2': 2402, 'N_FC': 1288, 'N_EL': 1267, 'N_DG': 186} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.555910e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 1717, 'N_WT': 10981, 'N_H2': 2188, 'N_FC': 1438, 'N_EL': 1400, 'N_DG': 37} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.779945e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.577455e-01 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 1339, 'N_WT': 7574, 'N_H2': 3109, 'N_FC': 553, 'N_EL': 1311, 'N_DG': 286} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.193203e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5882, 'N_WT': 5156, 'N_H2': 1742, 'N_FC': 1343, 'N_EL': 1023, 'N_DG': 203} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.128540e+00 | final_feasible=False | feasible_before_eval=True  [DEBUG EVAL MISMATCH] cfg={'N_PV': 1800, 'N_WT': 11217, 'N_H2': 2657, 'N_FC': 115, 'N_EL': 470, 'N_DG': 17} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.202879e+00 | final_feasible=False | feasible_before_eval=True
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5267, 'N_WT': 7518, 'N_H2': 1171, 'N_FC': 543, 'N_EL': 286, 'N_DG': 127} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=9.060192e-01 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2585, 'N_WT': 6573, 'N_H2': 2194, 'N_FC': 136, 'N_EL': 433, 'N_DG': 291} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.673596e-01 | final_feasible=False | feasible_before_eval=True
#   [DEBUG] Initial pop feasible flags AFTER evaluate(): [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
#   [DEBUG] Initial pop constraint arrays:
#     ind[ 0] constraints=[0.    , 0.    , 0.2964]  feasible=False
#     ind[ 1] constraints=[0.    , 0.    , 1.7397]  feasible=False
#     ind[ 2] constraints=[0.    , 0.    , 0.5727]  feasible=False
#     ind[ 3] constraints=[0.    , 0.    , 1.1421]  feasible=False
#     ind[ 4] constraints=[0.    , 0.    , 1.8424]  feasible=False
#     ind[ 5] constraints=[0.    , 0.    , 1.0092]  feasible=False
#     ind[ 6] constraints=[0.    , 0.    , 0.5986]  feasible=False
#     ind[ 7] constraints=[0.   , 0.   , 0.864]  feasible=False
#     ind[ 8] constraints=[0.    , 0.    , 1.7613]  feasible=False
#     ind[ 9] constraints=[0.    , 0.    , 1.5559]  feasible=False
#     ind[10] constraints=[0.    , 0.    , 0.6181]  feasible=False
#     ind[11] constraints=[0.    , 0.    , 0.2577]  feasible=False
#     ind[12] constraints=[0.    , 0.    , 1.3049]  feasible=False
#     ind[13] constraints=[0.    , 0.    , 1.7799]  feasible=False
#     ind[14] constraints=[0.    , 0.    , 1.5641]  feasible=False
#     ind[15] constraints=[0.    , 0.    , 1.1932]  feasible=False
#     ind[16] constraints=[0.    , 0.    , 1.2029]  feasible=False
#     ind[17] constraints=[0.    , 0.    , 0.7674]  feasible=False
#     ind[18] constraints=[0.    , 0.    , 1.1285]  feasible=False
#     ind[19] constraints=[0.   , 0.   , 0.906]  feasible=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2585, 'N_WT': 5157, 'N_H2': 2194, 'N_FC': 136, 'N_EL': 453, 'N_DG': 291} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.276036e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4730, 'N_WT': 3151, 'N_H2': 5772, 'N_FC': 143, 'N_EL': 94, 'N_DG': 116} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.178512e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5239, 'N_WT': 2084, 'N_H2': 213, 'N_FC': 564, 'N_EL': 502, 'N_DG': 115} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.224666e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 997, 'N_WT': 6225, 'N_H2': 793, 'N_FC': 63, 'N_EL': 705, 'N_DG': 111} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.906238e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5882, 'N_WT': 6572, 'N_H2': 1742, 'N_FC': 1343, 'N_EL': 1003, 'N_DG': 203} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.268303e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3680, 'N_WT': 9655, 'N_H2': 2279, 'N_FC': 14, 'N_EL': 327, 'N_DG': 218} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.009375e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 861, 'N_WT': 5966, 'N_H2': 785, 'N_FC': 736, 'N_EL': 731, 'N_DG': 136} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.405287e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4601, 'N_WT': 6913, 'N_H2': 261, 'N_FC': 735, 'N_EL': 192, 'N_DG': 137} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.463722e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2798, 'N_WT': 3181, 'N_H2': 5772, 'N_FC': 131, 'N_EL': 94, 'N_DG': 37} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.949967e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 772, 'N_WT': 9045, 'N_H2': 1653, 'N_FC': 138, 'N_EL': 1267, 'N_DG': 186} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.042313e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2585, 'N_WT': 6603, 'N_H2': 2315, 'N_FC': 136, 'N_EL': 404, 'N_DG': 291} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.759611e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2788, 'N_WT': 4445, 'N_H2': 1274, 'N_FC': 388, 'N_EL': 690, 'N_DG': 53} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.666034e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4720, 'N_WT': 4523, 'N_H2': 1196, 'N_FC': 453, 'N_EL': 690, 'N_DG': 133} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.159521e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2463, 'N_WT': 6573, 'N_H2': 1904, 'N_FC': 1286, 'N_EL': 433, 'N_DG': 291} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.205629e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 1906, 'N_WT': 8250, 'N_H2': 4900, 'N_FC': 55, 'N_EL': 1150, 'N_DG': 102} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.136738e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 760, 'N_WT': 6333, 'N_H2': 793, 'N_FC': 739, 'N_EL': 705, 'N_DG': 136} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.760627e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2374, 'N_WT': 6573, 'N_H2': 2194, 'N_FC': 136, 'N_EL': 433, 'N_DG': 146} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.363508e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3904, 'N_WT': 2761, 'N_H2': 2163, 'N_FC': 143, 'N_EL': 91, 'N_DG': 119} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.158429e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5110, 'N_WT': 10045, 'N_H2': 5888, 'N_FC': 14, 'N_EL': 345, 'N_DG': 215} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.314777e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2582, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 293} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.902245e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4720, 'N_WT': 2926, 'N_H2': 1196, 'N_FC': 453, 'N_EL': 690, 'N_DG': 133} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.562734e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3904, 'N_WT': 2761, 'N_H2': 2163, 'N_FC': 143, 'N_EL': 91, 'N_DG': 119} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.158429e-01 | final_feasible=False | feasible_before_eval=False  [DEBUG EVAL MISMATCH] cfg={'N_PV': 2788, 'N_WT': 4448, 'N_H2': 1274, 'N_FC': 388, 'N_EL': 690, 'N_DG': 53} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.669039e-01 | final_feasible=False | feasible_before_eval=False
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 144} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.579593e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3904, 'N_WT': 4634, 'N_H2': 2163, 'N_FC': 143, 'N_EL': 91, 'N_DG': 119} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.028070e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2788, 'N_WT': 4550, 'N_H2': 1274, 'N_FC': 599, 'N_EL': 690, 'N_DG': 53} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.614418e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2374, 'N_WT': 6573, 'N_H2': 2194, 'N_FC': 136, 'N_EL': 433, 'N_DG': 138} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.346663e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2582, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 292} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.900107e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3281, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 116, 'N_EL': 84, 'N_DG': 37} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.302669e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 997, 'N_WT': 6225, 'N_H2': 793, 'N_FC': 63, 'N_EL': 694, 'N_DG': 111} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.894172e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2337, 'N_WT': 1417, 'N_H2': 5772, 'N_FC': 137, 'N_EL': 69, 'N_DG': 37} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.203825e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.508543e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5152, 'N_WT': 3173, 'N_H2': 5760, 'N_FC': 579, 'N_EL': 512, 'N_DG': 115} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.398809e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.577455e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2832, 'N_WT': 3072, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 804, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.321212e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2788, 'N_WT': 4602, 'N_H2': 1274, 'N_FC': 447, 'N_EL': 690, 'N_DG': 53} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.059069e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5239, 'N_WT': 2084, 'N_H2': 177, 'N_FC': 564, 'N_EL': 506, 'N_DG': 115} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.202949e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2798, 'N_WT': 1265, 'N_H2': 5772, 'N_FC': 131, 'N_EL': 75, 'N_DG': 40} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.061107e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 3224, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 798, 'N_DG': 140} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.473692e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2788, 'N_WT': 4445, 'N_H2': 1310, 'N_FC': 388, 'N_EL': 686, 'N_DG': 53} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.687751e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 779, 'N_DG': 146} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.561061e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 157, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.392039e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2367, 'N_WT': 1351, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 147} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.625855e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.554624e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2582, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 299} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.869183e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.577455e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2586, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 288} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.891633e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2152, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 832, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.585539e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 753, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.480024e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.508543e-01 | final_feasible=False | feasible_before_eval=False  [DEBUG EVAL MISMATCH] cfg={'N_PV': 2478, 'N_WT': 1308, 'N_H2': 290, 'N_FC': 207, 'N_EL': 71, 'N_DG': 292} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=9.481802e-02 | final_feasible=False | feasible_before_eval=False
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 5239, 'N_WT': 2084, 'N_H2': 177, 'N_FC': 564, 'N_EL': 84, 'N_DG': 35} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.571610e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2832, 'N_WT': 3072, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 804, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.321212e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3385, 'N_WT': 1833, 'N_H2': 1835, 'N_FC': 116, 'N_EL': 792, 'N_DG': 37} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.482413e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.577455e-01 | final_feasible=False | feasible_before_eval=False  [DEBUG EVAL MISMATCH] cfg={'N_PV': 3281, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 116, 'N_EL': 506, 'N_DG': 117} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.172686e-01 | final_feasible=False | feasible_before_eval=False
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.508543e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 259, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.734205e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 144} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.579593e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 207, 'N_EL': 779, 'N_DG': 162} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.618077e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.508543e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3281, 'N_WT': 1833, 'N_H2': 367, 'N_FC': 116, 'N_EL': 506, 'N_DG': 117} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.281456e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 115, 'N_EL': 46, 'N_DG': 34} | LPSP=0.000072 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.184632e-01 | final_feasible=False | feasible_before_eval=False  [DEBUG EVAL MISMATCH] cfg={'N_PV': 2500, 'N_WT': 1308, 'N_H2': 290, 'N_FC': 116, 'N_EL': 86, 'N_DG': 292} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.821763e-02 | final_feasible=False | feasible_before_eval=False
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1259, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 753, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.480024e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3572, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 116, 'N_EL': 84, 'N_DG': 37} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.366370e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3281, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 202, 'N_EL': 817, 'N_DG': 146} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.902634e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3458, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 207, 'N_EL': 491, 'N_DG': 117} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.507382e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1902, 'N_FC': 157, 'N_EL': 779, 'N_DG': 139} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.378755e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2408, 'N_WT': 1648, 'N_H2': 1908, 'N_FC': 124, 'N_EL': 753, 'N_DG': 38} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.325968e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 1308, 'N_H2': 128, 'N_FC': 119, 'N_EL': 78, 'N_DG': 143} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.055766e-02 | final_feasible=False | feasible_before_eval=False  [DEBUG EVAL MISMATCH] cfg={'N_PV': 2478, 'N_WT': 833, 'N_H2': 290, 'N_FC': 207, 'N_EL': 54, 'N_DG': 292} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.853648e-02 | final_feasible=False | feasible_before_eval=False
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 186, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.497691e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3239, 'N_WT': 1833, 'N_H2': 1997, 'N_FC': 198, 'N_EL': 785, 'N_DG': 37} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.910861e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3244, 'N_WT': 1815, 'N_H2': 217, 'N_FC': 193, 'N_EL': 119, 'N_DG': 142} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.075262e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1908, 'N_FC': 157, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.392039e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2329, 'N_WT': 1260, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 944, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.689692e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2478, 'N_WT': 1308, 'N_H2': 228, 'N_FC': 156, 'N_EL': 71, 'N_DG': 299} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.455413e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1307, 'N_H2': 1908, 'N_FC': 201, 'N_EL': 779, 'N_DG': 146} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.560113e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 1970, 'N_FC': 208, 'N_EL': 779, 'N_DG': 143} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.626185e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2372, 'N_WT': 1308, 'N_H2': 315, 'N_FC': 118, 'N_EL': 95, 'N_DG': 140} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.490151e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2500, 'N_WT': 821, 'N_H2': 290, 'N_FC': 116, 'N_EL': 86, 'N_DG': 292} | LPSP=0.000002 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.664627e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 310, 'N_H2': 128, 'N_FC': 116, 'N_EL': 78, 'N_DG': 143} | LPSP=0.000005 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=0.000000e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2500, 'N_WT': 1308, 'N_H2': 290, 'N_FC': 116, 'N_EL': 92, 'N_DG': 151} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.495141e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2478, 'N_WT': 1246, 'N_H2': 290, 'N_FC': 207, 'N_EL': 55, 'N_DG': 292} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.852781e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 1308, 'N_H2': 128, 'N_FC': 119, 'N_EL': 86, 'N_DG': 284} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.516474e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3572, 'N_WT': 1844, 'N_H2': 217, 'N_FC': 119, 'N_EL': 84, 'N_DG': 37} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.587306e-02 | final_feasible=False | feasible_before_eval=False  [DEBUG EVAL MISMATCH] cfg={'N_PV': 2855, 'N_WT': 130, 'N_H2': 1883, 'N_FC': 155, 'N_EL': 770, 'N_DG': 295} | LPSP=0.000005 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.006058e-01 | final_feasible=False | feasible_before_eval=False
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3281, 'N_WT': 2833, 'N_H2': 217, 'N_FC': 116, 'N_EL': 84, 'N_DG': 37} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.515819e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2317, 'N_WT': 1295, 'N_H2': 217, 'N_FC': 116, 'N_EL': 93, 'N_DG': 37} | LPSP=0.000039 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.868373e-04 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3281, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 116, 'N_EL': 54, 'N_DG': 38} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.995943e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3572, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 116, 'N_EL': 84, 'N_DG': 40} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.433685e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3572, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 116, 'N_EL': 84, 'N_DG': 41} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.456123e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3447, 'N_WT': 1846, 'N_H2': 1902, 'N_FC': 157, 'N_EL': 770, 'N_DG': 139} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.900716e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2478, 'N_WT': 833, 'N_H2': 290, 'N_FC': 207, 'N_EL': 84, 'N_DG': 291} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.258346e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2478, 'N_WT': 1294, 'N_H2': 290, 'N_FC': 207, 'N_EL': 54, 'N_DG': 289} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=9.154603e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3260, 'N_WT': 1815, 'N_H2': 217, 'N_FC': 122, 'N_EL': 75, 'N_DG': 33} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.166221e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3556, 'N_WT': 1833, 'N_H2': 217, 'N_FC': 187, 'N_EL': 84, 'N_DG': 146} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.046532e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2478, 'N_WT': 1308, 'N_H2': 1926, 'N_FC': 156, 'N_EL': 71, 'N_DG': 300} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.979063e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 1295, 'N_H2': 58, 'N_FC': 205, 'N_EL': 78, 'N_DG': 34} | LPSP=0.000676 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.205285e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3260, 'N_WT': 1815, 'N_H2': 217, 'N_FC': 116, 'N_EL': 75, 'N_DG': 33} | LPSP=0.000007 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.934793e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 1389, 'N_H2': 128, 'N_FC': 119, 'N_EL': 78, 'N_DG': 148} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.892832e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2317, 'N_WT': 1308, 'N_H2': 218, 'N_FC': 116, 'N_EL': 93, 'N_DG': 146} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.831002e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3282, 'N_WT': 1776, 'N_H2': 218, 'N_FC': 161, 'N_EL': 78, 'N_DG': 154} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.969900e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2317, 'N_WT': 1295, 'N_H2': 217, 'N_FC': 122, 'N_EL': 93, 'N_DG': 37} | LPSP=0.000024 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.038966e-03 | final_feasible=False | feasible_before_eval=False  [DEBUG EVAL MISMATCH] cfg={'N_PV': 3572, 'N_WT': 1886, 'N_H2': 217, 'N_FC': 116, 'N_EL': 84, 'N_DG': 57} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.326871e-02 | final_feasible=False | feasible_before_eval=False
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 1308, 'N_H2': 128, 'N_FC': 65, 'N_EL': 46, 'N_DG': 143} | LPSP=0.000002 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.109506e-04 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2500, 'N_WT': 1308, 'N_H2': 290, 'N_FC': 116, 'N_EL': 81, 'N_DG': 151} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.374427e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 310, 'N_H2': 111, 'N_FC': 116, 'N_EL': 79, 'N_DG': 140} | LPSP=0.000005 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=0.000000e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2321, 'N_WT': 1308, 'N_H2': 315, 'N_FC': 118, 'N_EL': 95, 'N_DG': 36} | LPSP=0.000042 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=9.858134e-03 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2500, 'N_WT': 1308, 'N_H2': 290, 'N_FC': 116, 'N_EL': 92, 'N_DG': 151} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.495141e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2368, 'N_WT': 1295, 'N_H2': 37, 'N_FC': 116, 'N_EL': 93, 'N_DG': 141} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.367637e-02 | final_feasible=False | feasible_before_eval=False  [DEBUG EVAL MISMATCH] cfg={'N_PV': 2372, 'N_WT': 1308, 'N_H2': 332, 'N_FC': 118, 'N_EL': 94, 'N_DG': 143} | LPSP=0.000001 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.674444e-02 | final_feasible=False | feasible_before_eval=False
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2367, 'N_WT': 1309, 'N_H2': 219, 'N_FC': 116, 'N_EL': 84, 'N_DG': 33} | LPSP=0.000084 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.856899e-04 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2500, 'N_WT': 821, 'N_H2': 217, 'N_FC': 116, 'N_EL': 86, 'N_DG': 292} | LPSP=0.000002 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.231680e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3577, 'N_WT': 1832, 'N_H2': 313, 'N_FC': 208, 'N_EL': 95, 'N_DG': 144} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.205310e-01 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2319, 'N_WT': 1295, 'N_H2': 290, 'N_FC': 116, 'N_EL': 93, 'N_DG': 37} | LPSP=0.000039 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.084245e-03 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2367, 'N_WT': 1309, 'N_H2': 219, 'N_FC': 206, 'N_EL': 84, 'N_DG': 27} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.392219e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 310, 'N_H2': 215, 'N_FC': 116, 'N_EL': 84, 'N_DG': 143} | LPSP=0.000005 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=0.000000e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 1307, 'N_H2': 127, 'N_FC': 205, 'N_EL': 78, 'N_DG': 140} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.062894e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2413, 'N_WT': 310, 'N_H2': 213, 'N_FC': 116, 'N_EL': 95, 'N_DG': 143} | LPSP=0.000005 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=0.000000e+00 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2397, 'N_WT': 1309, 'N_H2': 219, 'N_FC': 116, 'N_EL': 84, 'N_DG': 33} | LPSP=0.000084 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.429860e-04 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2319, 'N_WT': 1295, 'N_H2': 290, 'N_FC': 116, 'N_EL': 93, 'N_DG': 39} | LPSP=0.000021 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.565077e-03 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2415, 'N_WT': 1295, 'N_H2': 179, 'N_FC': 121, 'N_EL': 94, 'N_DG': 144} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.581610e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2370, 'N_WT': 1308, 'N_H2': 290, 'N_FC': 116, 'N_EL': 91, 'N_DG': 37} | LPSP=0.000038 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.174010e-03 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 218, 'N_FC': 112, 'N_EL': 93, 'N_DG': 144} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.653395e-02 | final_feasible=False | feasible_before_eval=False
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2370, 'N_WT': 1295, 'N_H2': 132, 'N_FC': 122, 'N_EL': 78, 'N_DG': 60} | LPSP=0.000002 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.027298e-04 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2371, 'N_WT': 1308, 'N_H2': 408, 'N_FC': 115, 'N_EL': 80, 'N_DG': 24} | LPSP=0.000473 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.103613e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2414, 'N_WT': 1308, 'N_H2': 304, 'N_FC': 122, 'N_EL': 76, 'N_DG': 24} | LPSP=0.000349 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.805415e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2412, 'N_WT': 1359, 'N_H2': 214, 'N_FC': 115, 'N_EL': 75, 'N_DG': 25} | LPSP=0.000366 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.505275e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2315, 'N_WT': 273, 'N_H2': 128, 'N_FC': 66, 'N_EL': 33, 'N_DG': 72} | LPSP=0.003309 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=0.000000e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2560, 'N_WT': 1545, 'N_H2': 211, 'N_FC': 115, 'N_EL': 60, 'N_DG': 9} | LPSP=0.001552 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.392337e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2561, 'N_WT': 1571, 'N_H2': 210, 'N_FC': 116, 'N_EL': 59, 'N_DG': 24} | LPSP=0.000232 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.001012e-02 | final_feasible=False | feasible_before_eval=True
#   Gen   10  |  feasible:  20  |      2.98e+05          4395  |  113s
#     Best: N_PV=2372  N_WT=366  N_H2= 57  N_FC= 57  N_EL= 48  N_DG= 24  ->  Cost=2.98e+05  Emissions=1.179e+05
#     [DEBUG GEN 10]  offspring stale_feasible_true=20  stale_feasible_false=0
#     [DEBUG GEN 10]  COMBINED (40): feasible=33  infeasible=7  rank0_feasible=12
#     [DEBUG GEN 10]  POP after truncation (20): feasible=20  infeasible=0  rank0_feasible=12  rank0_infeasible=0
#     [DEBUG GEN 10]  history feasible count (used for print above): 20  (fallback to pop? False)
#
#   =============================================================
#   [DEBUG FEASIBILITY REPORT] Gen 10 — POP after truncation
#   =============================================================
#   Total pop       : 20
#   Feasible        : 20  /  20
#   Infeasible      : 0  /  20
#   Rank-0 total    : 12
#   Rank-0 feasible : 12
#   Rank-0 infeasible:0
#   -------------------------------------------------------------
#   Constraint violation stats (feasible individuals — should all be ~0):
#     viol_reliability: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_diesel_fraction: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_custom: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#   =============================================================
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2369, 'N_WT': 396, 'N_H2': 254, 'N_FC': 67, 'N_EL': 45, 'N_DG': 66} | LPSP=0.002453 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=0.000000e+00 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2412, 'N_WT': 1729, 'N_H2': 59, 'N_FC': 65, 'N_EL': 46, 'N_DG': 24} | LPSP=0.001240 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.948638e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2315, 'N_WT': 2097, 'N_H2': 131, 'N_FC': 115, 'N_EL': 48, 'N_DG': 10} | LPSP=0.000518 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.023719e-02 | final_feasible=False | feasible_before_eval=True
#   Gen   20  |  feasible:  20  |     2.782e+05          2483  |  217s
#     Best: N_PV=2510  N_WT=413  N_H2= 14  N_FC= 28  N_EL= 48  N_DG= 24  ->  Cost=2.782e+05  Emissions=1.096e+05
#     [DEBUG GEN 20]  offspring stale_feasible_true=20  stale_feasible_false=0
#     [DEBUG GEN 20]  COMBINED (40): feasible=34  infeasible=6  rank0_feasible=18
#     [DEBUG GEN 20]  POP after truncation (20): feasible=20  infeasible=0  rank0_feasible=18  rank0_infeasible=0
#     [DEBUG GEN 20]  history feasible count (used for print above): 20  (fallback to pop? False)
#
#   =============================================================
#   [DEBUG FEASIBILITY REPORT] Gen 20 — POP after truncation
#   =============================================================
#   Total pop       : 20
#   Feasible        : 20  /  20
#   Infeasible      : 0  /  20
#   Rank-0 total    : 18
#   Rank-0 feasible : 18
#   Rank-0 infeasible:0
#   -------------------------------------------------------------
#   Constraint violation stats (feasible individuals — should all be ~0):
#     viol_reliability: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_diesel_fraction: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_custom: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#   =============================================================
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2517, 'N_WT': 1272, 'N_H2': 53, 'N_FC': 178, 'N_EL': 36, 'N_DG': 23} | LPSP=0.004650 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.892919e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2510, 'N_WT': 1272, 'N_H2': 57, 'N_FC': 175, 'N_EL': 36, 'N_DG': 23} | LPSP=0.004505 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.936455e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2905, 'N_WT': 1262, 'N_H2': 59, 'N_FC': 327, 'N_EL': 53, 'N_DG': 1} | LPSP=0.005481 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.925740e-02 | final_feasible=False | feasible_before_eval=True
#   Gen   30  |  feasible:  20  |     2.759e+05         379.8  |  320s
#     Best: N_PV=2505  N_WT=413  N_H2= 13  N_FC= 28  N_EL= 36  N_DG= 24  ->  Cost=2.759e+05  Emissions=1.121e+05
#     [DEBUG GEN 30]  offspring stale_feasible_true=20  stale_feasible_false=0
#     [DEBUG GEN 30]  COMBINED (40): feasible=36  infeasible=4  rank0_feasible=30
#     [DEBUG GEN 30]  POP after truncation (20): feasible=20  infeasible=0  rank0_feasible=20  rank0_infeasible=0
#     [DEBUG GEN 30]  history feasible count (used for print above): 20  (fallback to pop? False)
#
#   =============================================================
#   [DEBUG FEASIBILITY REPORT] Gen 30 — POP after truncation
#   =============================================================
#   Total pop       : 20
#   Feasible        : 20  /  20
#   Infeasible      : 0  /  20
#   Rank-0 total    : 20
#   Rank-0 feasible : 20
#   Rank-0 infeasible:0
#   -------------------------------------------------------------
#   Constraint violation stats (feasible individuals — should all be ~0):
#     viol_reliability: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_diesel_fraction: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_custom: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#   =============================================================
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2905, 'N_WT': 1272, 'N_H2': 61, 'N_FC': 239, 'N_EL': 52, 'N_DG': 1} | LPSP=0.005297 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.485790e-02 | final_feasible=False | feasible_before_eval=True
# ...
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 2859, 'N_WT': 2039, 'N_H2': 6, 'N_FC': 9, 'N_EL': 26, 'N_DG': 1} | LPSP=0.011987 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.117486e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3456, 'N_WT': 1185, 'N_H2': 108, 'N_FC': 177, 'N_EL': 95, 'N_DG': 1} | LPSP=0.001058 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.576135e-04 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4446, 'N_WT': 1187, 'N_H2': 103, 'N_FC': 171, 'N_EL': 95, 'N_DG': 1} | LPSP=0.001141 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.239245e-04 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3378, 'N_WT': 1090, 'N_H2': 105, 'N_FC': 303, 'N_EL': 95, 'N_DG': 13} | LPSP=0.000910 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.429372e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3374, 'N_WT': 1182, 'N_H2': 105, 'N_FC': 192, 'N_EL': 95, 'N_DG': 1} | LPSP=0.000906 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.865355e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3374, 'N_WT': 1187, 'N_H2': 187, 'N_FC': 171, 'N_EL': 95, 'N_DG': 1} | LPSP=0.001141 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=3.918775e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3447, 'N_WT': 1227, 'N_H2': 103, 'N_FC': 168, 'N_EL': 187, 'N_DG': 1} | LPSP=0.001164 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.065053e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3447, 'N_WT': 1227, 'N_H2': 104, 'N_FC': 174, 'N_EL': 187, 'N_DG': 1} | LPSP=0.000945 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.309388e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3374, 'N_WT': 1187, 'N_H2': 105, 'N_FC': 180, 'N_EL': 95, 'N_DG': 4} | LPSP=0.000760 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.195547e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3374, 'N_WT': 1186, 'N_H2': 103, 'N_FC': 173, 'N_EL': 95, 'N_DG': 9} | LPSP=0.000516 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.727224e-04 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3447, 'N_WT': 1227, 'N_H2': 107, 'N_FC': 171, 'N_EL': 95, 'N_DG': 1} | LPSP=0.001049 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.023368e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3374, 'N_WT': 1198, 'N_H2': 106, 'N_FC': 172, 'N_EL': 101, 'N_DG': 21} | LPSP=0.000035 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.494002e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3374, 'N_WT': 1187, 'N_H2': 105, 'N_FC': 171, 'N_EL': 92, 'N_DG': 18} | LPSP=0.000147 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.375458e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 4476, 'N_WT': 1208, 'N_H2': 112, 'N_FC': 174, 'N_EL': 99, 'N_DG': 17} | LPSP=0.000070 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.912897e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3446, 'N_WT': 1227, 'N_H2': 25, 'N_FC': 170, 'N_EL': 185, 'N_DG': 1} | LPSP=0.005146 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=6.051098e-03 | final_feasible=False | feasible_before_eval=True
#   Gen  380  |  feasible:  20  |     2.651e+05         198.1  |  3928s
#     Best: N_PV=2769  N_WT=576  N_H2=  2  N_FC=  5  N_EL=  7  N_DG= 19  ->  Cost=2.651e+05  Emissions=7.578e+04
#     [DEBUG GEN 380]  offspring stale_feasible_true=20  stale_feasible_false=0
#     [DEBUG GEN 380]  COMBINED (40): feasible=31  infeasible=9  rank0_feasible=21
#     [DEBUG GEN 380]  POP after truncation (20): feasible=20  infeasible=0  rank0_feasible=20  rank0_infeasible=0
#     [DEBUG GEN 380]  history feasible count (used for print above): 20  (fallback to pop? False)
#
#   =============================================================
#   [DEBUG FEASIBILITY REPORT] Gen 380 — POP after truncation
#   =============================================================
#   Total pop       : 20
#   Feasible        : 20  /  20
#   Infeasible      : 0  /  20
#   Rank-0 total    : 20
#   Rank-0 feasible : 20
#   Rank-0 infeasible:0
#   -------------------------------------------------------------
#   Constraint violation stats (feasible individuals — should all be ~0):
#     viol_reliability: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_diesel_fraction: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_custom: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#   =============================================================
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3426, 'N_WT': 1227, 'N_H2': 108, 'N_FC': 171, 'N_EL': 103, 'N_DG': 1} | LPSP=0.001049 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.930312e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3544, 'N_WT': 1187, 'N_H2': 104, 'N_FC': 177, 'N_EL': 93, 'N_DG': 1} | LPSP=0.001109 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.273711e-04 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 2012, 'N_H2': 104, 'N_FC': 169, 'N_EL': 95, 'N_DG': 17} | LPSP=0.000000 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.024001e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1187, 'N_H2': 105, 'N_FC': 206, 'N_EL': 95, 'N_DG': 1} | LPSP=0.000782 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.192084e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3392, 'N_WT': 1187, 'N_H2': 105, 'N_FC': 172, 'N_EL': 95, 'N_DG': 12} | LPSP=0.000317 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=8.092229e-04 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3188, 'N_WT': 2021, 'N_H2': 58, 'N_FC': 172, 'N_EL': 95, 'N_DG': 1} | LPSP=0.000164 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.518096e-02 | final_feasible=False | feasible_before_eval=True
#   Gen  390  |  feasible:  20  |     2.651e+05         192.5  |  4032s
#     Best: N_PV=2769  N_WT=576  N_H2=  2  N_FC=  5  N_EL=  7  N_DG= 19  ->  Cost=2.651e+05  Emissions=7.578e+04
#     [DEBUG GEN 390]  offspring stale_feasible_true=20  stale_feasible_false=0
#     [DEBUG GEN 390]  COMBINED (40): feasible=33  infeasible=7  rank0_feasible=27
#     [DEBUG GEN 390]  POP after truncation (20): feasible=20  infeasible=0  rank0_feasible=20  rank0_infeasible=0
#     [DEBUG GEN 390]  history feasible count (used for print above): 20  (fallback to pop? False)
#
#   =============================================================
#   [DEBUG FEASIBILITY REPORT] Gen 390 — POP after truncation
#   =============================================================
#   Total pop       : 20
#   Feasible        : 20  /  20
#   Infeasible      : 0  /  20
#   Rank-0 total    : 20
#   Rank-0 feasible : 20
#   Rank-0 infeasible:0
#   -------------------------------------------------------------
#   Constraint violation stats (feasible individuals — should all be ~0):
#     viol_reliability: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_diesel_fraction: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_custom: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#   =============================================================
#
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1187, 'N_H2': 195, 'N_FC': 172, 'N_EL': 95, 'N_DG': 1} | LPSP=0.001102 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.898814e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1187, 'N_H2': 105, 'N_FC': 172, 'N_EL': 111, 'N_DG': 1} | LPSP=0.001102 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.225680e-04 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1206, 'N_H2': 104, 'N_FC': 172, 'N_EL': 95, 'N_DG': 4} | LPSP=0.000838 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.362154e-04 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1187, 'N_H2': 105, 'N_FC': 172, 'N_EL': 123, 'N_DG': 1} | LPSP=0.001102 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.440293e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1317, 'N_H2': 105, 'N_FC': 173, 'N_EL': 95, 'N_DG': 1} | LPSP=0.000809 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.103415e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1771, 'N_H2': 104, 'N_FC': 174, 'N_EL': 95, 'N_DG': 1} | LPSP=0.000281 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.521111e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1188, 'N_H2': 174, 'N_FC': 173, 'N_EL': 95, 'N_DG': 19} | LPSP=0.000054 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.781675e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3018, 'N_WT': 1187, 'N_H2': 105, 'N_FC': 215, 'N_EL': 98, 'N_DG': 1} | LPSP=0.000854 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.511060e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1426, 'N_H2': 33, 'N_FC': 172, 'N_EL': 95, 'N_DG': 1} | LPSP=0.002295 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.604127e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1188, 'N_H2': 104, 'N_FC': 296, 'N_EL': 95, 'N_DG': 1} | LPSP=0.000758 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=4.792623e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3328, 'N_WT': 1076, 'N_H2': 104, 'N_FC': 233, 'N_EL': 98, 'N_DG': 1} | LPSP=0.001603 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.260829e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1196, 'N_H2': 104, 'N_FC': 172, 'N_EL': 95, 'N_DG': 16} | LPSP=0.000144 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=2.420789e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3395, 'N_WT': 1330, 'N_H2': 98, 'N_FC': 166, 'N_EL': 98, 'N_DG': 1} | LPSP=0.001008 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=9.362652e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3444, 'N_WT': 1243, 'N_H2': 103, 'N_FC': 180, 'N_EL': 89, 'N_DG': 20} | LPSP=0.000057 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=1.027116e-02 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3018, 'N_WT': 1188, 'N_H2': 105, 'N_FC': 172, 'N_EL': 170, 'N_DG': 1} | LPSP=0.001100 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=5.948104e-03 | final_feasible=False | feasible_before_eval=True
#   [DEBUG EVAL MISMATCH] cfg={'N_PV': 3376, 'N_WT': 1339, 'N_H2': 27, 'N_FC': 171, 'N_EL': 98, 'N_DG': 1} | LPSP=0.003893 lpsp_viol=0.000000e+00 lpsp_alone_feasible=True | custom_viol=7.381011e-03 | final_feasible=False | feasible_before_eval=True
#   Gen  400  |  feasible:  20  |     2.651e+05         192.2  |  4136s
#     Best: N_PV=2769  N_WT=576  N_H2=  2  N_FC=  5  N_EL=  7  N_DG= 19  ->  Cost=2.651e+05  Emissions=7.578e+04
#     [DEBUG GEN 400]  offspring stale_feasible_true=20  stale_feasible_false=0
#     [DEBUG GEN 400]  COMBINED (40): feasible=36  infeasible=4  rank0_feasible=29
#     [DEBUG GEN 400]  POP after truncation (20): feasible=20  infeasible=0  rank0_feasible=20  rank0_infeasible=0
#     [DEBUG GEN 400]  history feasible count (used for print above): 20  (fallback to pop? False)
#
#   =============================================================
#   [DEBUG FEASIBILITY REPORT] Gen 400 — POP after truncation
#   =============================================================
#   Total pop       : 20
#   Feasible        : 20  /  20
#   Infeasible      : 0  /  20
#   Rank-0 total    : 20
#   Rank-0 feasible : 20
#   Rank-0 infeasible:0
#   -------------------------------------------------------------
#   Constraint violation stats (feasible individuals — should all be ~0):
#     viol_reliability: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_diesel_fraction: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#     viol_custom: min=0.0000e+00  max=0.0000e+00  mean=0.0000e+00  n_actually_violated=0/20
#   =============================================================
#
#
#   [DEBUG FINAL] pop size=20
#   [DEBUG FINAL] rank-0 total=20
#   [DEBUG FINAL] rank-0 feasible=20
#   [DEBUG FINAL] rank-0 infeasible=0
#   [DEBUG FINAL] pareto list used for CSV: 20 solutions
#     pareto[0] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[1] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[2] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[3] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[4] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[5] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[6] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[7] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[8] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[9] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[10] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[11] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[12] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[13] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[14] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[15] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[16] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[17] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[18] feasible=True  rank=0  constraints=[0., 0., 0.]
#     pareto[19] feasible=True  rank=0  constraints=[0., 0., 0.]
# =================================================================
#   Done in 4135.6s  |  Pareto solutions: 20
#   Saved: /kaggle/working/pareto_front.csv  |  /kaggle/working/optimization_history.csv
# =================================================================
#
# Best solution by Cost:
# N_PV                             2769
# N_WT                              576
# N_H2                                2
# N_FC                                5
# N_EL                                7
# N_DG                               19
# Cost                    265134.770411
# Emissions                75784.770117
# viol_reliability                  0.0
# viol_diesel_fraction              0.0
# feasible                         True
# Name: 0, dtype: object
#
# Best solution by Emissions:
# N_PV                            3376
# N_WT                            1188
# N_H2                             104
# N_FC                             172
# N_EL                              95
# N_DG                               1
# Cost                    490383.79287
# Emissions                 192.197323
# viol_reliability                 0.0
# viol_diesel_fraction             0.0
# feasible                        True
# Name: 1, dtype: object
